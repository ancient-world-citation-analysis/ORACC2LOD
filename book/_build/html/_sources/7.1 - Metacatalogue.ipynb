# %% [markdown]
# #Metacatalogue
#
# Notebook by Melinee Her
#
# Cleans the megacatalogue and harmonizes ORACC data with CDLI catalogue.

# %% [markdown]
# #Merging the cdli_cat and megacat_mini
#
# 1. Read in the [cdli_cat_short csv](https://docs.google.com/spreadsheets/d/1wiViebAL3xGGwV75cKIr41beRX-Lxuj4u8y1ET8I27Y/edit?usp=sharing)
#   * This can be replaced by the workflow in this notebook: https://drive.google.com/file/d/1yhM_8fgF6p89E3qiH1LRK4EgEau7HLuT/view?usp=sharing
#   * This notebook also provides the headers / format for LOD triples in FactGrid.
# 2. Match the CDLI `id_text` with the ORACC `id_text` in ORACC [Megacatalog_short](https://docs.google.com/spreadsheets/d/
# 1iyvVpt5DrkF22Cd_p_oWHZfHsd6NzcvUlowS2_7Cm2U/edit?usp=sharing)
#
# 3. After the preliminary matching of the fields, we will want to make a final subset of the columns we will add to our Wikibase in FactGrid. To do this we also need to see if the values are different for a given field.
# * Is there a way to highlight different values which we expect to be the same?
#
# 4. Lastly, using this notebook, we will obtain the proper Wikibase formatting for FactGrid header fields: https://drive.google.com/file/d/1yhM_8fgF6p89E3qiH1LRK4EgEau7HLuT/view?usp=sharing
# * the subset of 8 fields we selected is only the beginning, but it is a good start.
# * If the values are identical we can use the Q-items and build the final CSV for a [QuickStatements]() import.

# %% [markdown]
# # Mount Google Drive folder + imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#any necessary imports
import pandas as pd
import zipfile
from zipfile import ZipFile
import json
import requests
from tqdm import tqdm
import os
import errno
import re
import random
import numpy as np
import sys
import copy
import networkx as nx
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import collections

#Set folder for remote drive
#folder = '/content/drive/My Drive/FactGrid Cuneiform (AWCA)/people/Melinee/'
folder = '/content/drive/MyDrive/Melinee/'

#importing utils for the method which downloads the current text json files
os.chdir(folder + 'network/utils/')
from utils import oracc_download

# This is a user defined module that searches through the texts to find the entities in the text that
# are people and places, to be imported as nodes into the network
os.chdir(folder + 'network/')
import rank_parser4 as rp

pd.set_option('display.max_columns', None)

# %% [markdown]
# #Shortening the ORACC Megacatalogue
#
# In this section of the notebook, we will create a smaller version of the megacatalogue, selectin a subset of columns to compare to the CDLI data when forming the metacatalogue.

# %% [markdown]
# Retrieving the megacatalogue

# %%
#path = '/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_DFS/megacatalogue.csv'
path = folder + 'ORACC_DFS/megacatalogue.csv'
megacatalogue = pd.read_csv(path, low_memory=False, index_col=0)

# %%
megacatalogue.head(3)
# Out:
#    id_text       langs    project id_text.1 primary_publication  \
# 0  P522592  0x08000000  tilbarsip   P522592       Til-Barsip 01
# 1  P522593  0x08000000  tilbarsip   P522593       Til-Barsip 02
# 2  P522594  0x08000000  tilbarsip   P522594       Til-Barsip 03
#
#                provenience  pleiades_id            pleiades_coord  \
# 0  Tell Ahmar (Til Barsip)     658410.0  [38.1191944, 36.6749623]
# 1  Tell Ahmar (Til Barsip)     658410.0  [38.1191944, 36.6749623]
# 2  Tell Ahmar (Til Barsip)     658410.0  [38.1191944, 36.6749623]
#
#   excavation_no                          archive  \
# 0          T 01  001 -  Hanni Archive (House C1)
# 1          T 02  001 -  Hanni Archive (House C1)
# 2          T 03  001 -  Hanni Archive (House C1)
#
#                                     atae_attribution  \
# 0  Adapted from Stephanie Dalley, “Neo-Assyrian T...
# 1  Adapted from Stephanie Dalley, “Neo-Assyrian T...
# 2  Adapted from Stephanie Dalley, “Neo-Assyrian T...
#
#                                              cite_as  \
# 0  Please cite this page as http://oracc.org/atae...
# 1  Please cite this page as http://oracc.org/atae...
# 2  Please cite this page as http://oracc.org/atae...
#
#                                 collection composite_witness  \
# 0  National Museum of Syria, Aleppo, Syria           witness
# 1  National Museum of Syria, Aleppo, Syria           witness
# 2  National Museum of Syria, Aleppo, Syria           witness
#
#                                              credits  \
# 0  Adapted from Stephanie Dalley, “Neo-Assyrian T...
# 1  Adapted from Stephanie Dalley, “Neo-Assyrian T...
# 2  Adapted from Stephanie Dalley, “Neo-Assyrian T...
#
#                                 date_of_origin    designation       dialect  \
# 0                                 00.000.00.00  Til-Barsip 01  Neo-Assyrian
# 1                                 00.000.07.00  Til-Barsip 02  Neo-Assyrian
# 2  Assurbanipal.limu Bel-Harran-shaddu’a.07.01  Til-Barsip 03  Neo-Assyrian
#
#                    genre                           has_date  language  \
# 0  Administrative Record                                 no  Akkadian
# 1      Legal Transaction  yes, but date partially preserved  Akkadian
# 2      Legal Transaction                                yes  Akkadian
#
#   last_mod_by last_modified               list_name material object_type  \
# 0       ARMEP    27.01.2022  atae/tilbarsip:P522592     clay      tablet
# 1       ARMEP    27.01.2022  atae/tilbarsip:P522593     clay      tablet
# 2       ARMEP    27.01.2022  atae/tilbarsip:P522594     clay    envelope
#
#          period        script script_remarks script_type sealed_marked  \
# 0  Neo-Assyrian  Neo-Assyrian      inscribed   Cuneiform            no
# 1  Neo-Assyrian  Neo-Assyrian      inscribed   Cuneiform            no
# 2  Neo-Assyrian  Neo-Assyrian      inscribed   Cuneiform       unknown
#
#          subgenre             date  \
# 0  list (rations)              NaN
# 1       debt note  [...]-VII-[...]
# 2             NaN       650-VII-01
#
#                                         long_date ancient_creditor  \
# 0                                             NaN              NaN
# 1        Tašrītu [...th], eponymy of Ašš[ur?-...]            Hanni
# 2  Tašrītu 1[st], eponymy of Bēl-Harrān-šadd[û’a]              NaN
#
#    ancient_debtor         date_gen    day  \
# 0             NaN              NaN    NaN
# 1  Nabû-kin-[...]  [...]-VII-[...]  [...]
# 2             NaN       650-VII-01     01
#
#                                 long_date_gen month   year  \
# 0                                         NaN   NaN    NaN
# 1             Tašrītu ...th, [eponymy of ...]   VII  [...]
# 2  Tašrītu 1st, eponymy of Bēl-Harrān-šaddû’a   VII    650
#
#                eponym    regnal_dates         ruler ancient_buyer  \
# 0                 NaN             NaN           NaN           NaN
# 1                 NaN             NaN           NaN           NaN
# 2  Bēl-Harrān-šaddû’a  668–ca. 631 BC  Ashurbanipal           NaN
#
#   ancient_seller seal_mark_type seal_owner ancient_author museum-nos copies  \
# 0            NaN            NaN        NaN            NaN        NaN    NaN
# 1            NaN            NaN        NaN            NaN        NaN    NaN
# 2            NaN            NaN        NaN            NaN        NaN    NaN
#
#   photos editions translations secondary-literatures mus_no  \
# 0    NaN      NaN          NaN                   NaN    NaN
# 1    NaN      NaN          NaN                   NaN    NaN
# 2    NaN      NaN          NaN                   NaN    NaN
#
#   publication_history recipient title supergenre xproject  uri public images  \
# 0                 NaN       NaN   NaN        NaN      NaN  NaN    NaN    NaN
# 1                 NaN       NaN   NaN        NaN      NaN  NaN    NaN    NaN
# 2                 NaN       NaN   NaN        NaN      NaN  NaN    NaN    NaN
#
#   trans q_number translations-moran-1992s copy photo museum_no text_comments  \
# 0   NaN      NaN                      NaN  NaN   NaN       NaN           NaN
# 1   NaN      NaN                      NaN  NaN   NaN       NaN           NaN
# 2   NaN      NaN                      NaN  NaN   NaN       NaN           NaN
#
#   accession_no ancient_year date_bce months_recorded tablet_comments  \
# 0          NaN          NaN      NaN             NaN             NaN
# 1          NaN          NaN      NaN             NaN             NaN
# 2          NaN          NaN      NaN             NaN             NaN
#
#   date_comments bibilography author publication_date atae_lists cdli_id  \
# 0           NaN          NaN    NaN              NaN        NaN     NaN
# 1           NaN          NaN    NaN              NaN        NaN     NaN
# 2           NaN          NaN    NaN              NaN        NaN     NaN
#
#   cdli_museum_no ch_name ch_no ch_num_name comp_wit display_name edited_twice  \
# 0            NaN     NaN   NaN         NaN      NaN          NaN          NaN
# 1            NaN     NaN   NaN         NaN      NaN          NaN          NaN
# 2            NaN     NaN   NaN         NaN      NaN          NaN          NaN
#
#   lka_no oracc_header other_pub please_cite proposed_date rework  \
# 0    NaN          NaN       NaN         NaN           NaN    NaN
# 1    NaN          NaN       NaN         NaN           NaN    NaN
# 2    NaN          NaN       NaN         NaN           NaN    NaN
#
#   saa_attribution saa_cdli_id saa_cdli_museum saao_lists secondary_record  \
# 0             NaN         NaN             NaN        NaN              NaN
# 1             NaN         NaN             NaN        NaN              NaN
# 2             NaN         NaN             NaN        NaN              NaN
#
#   short_title vol_title volume pkt_no cdli_excavation_no editorial_comments  \
# 0         NaN       NaN    NaN    NaN                NaN                NaN
# 1         NaN       NaN    NaN    NaN                NaN                NaN
# 2         NaN       NaN    NaN    NaN                NaN                NaN
#
#   kar_no saa_cdli_excavation kav_no eponym_title dossier_list kah_no nargd_no  \
# 0    NaN                 NaN    NaN          NaN          NaN    NaN      NaN
# 1    NaN                 NaN    NaN          NaN          NaN    NaN      NaN
# 2    NaN                 NaN    NaN          NaN          NaN    NaN      NaN
#
#   pkta_no findspot_square gpa_no external_id temp_id tim_11_no title_in_date  \
# 0     NaN             NaN    NaN         NaN     NaN       NaN           NaN
# 1     NaN             NaN    NaN         NaN     NaN       NaN           NaN
# 2     NaN             NaN    NaN         NaN     NaN       NaN           NaN
#
#   abl_no ancient_recipient cdli_accession_no pleiades_sender_loc  \
# 0    NaN               NaN               NaN                 NaN
# 1    NaN               NaN               NaN                 NaN
# 2    NaN               NaN               NaN                 NaN
#
#   saa_cdli_accession sender_loc sender_loc_coordinates ct_54_no astron_date  \
# 0                NaN        NaN                    NaN      NaN         NaN
# 1                NaN        NaN                    NaN      NaN         NaN
# 2                NaN        NaN                    NaN      NaN         NaN
#
#   rma_no prt_no dossier ags_no add_no ct_53_no las_no adb_no  ex1 ex1id  ex2  \
# 0    NaN    NaN     NaN    NaN    NaN      NaN    NaN    NaN  NaN   NaN  NaN
# 1    NaN    NaN     NaN    NaN    NaN      NaN    NaN    NaN  NaN   NaN  NaN
# 2    NaN    NaN     NaN    NaN    NaN      NaN    NaN    NaN  NaN   NaN  NaN
#
#   ex2id  ex3 ex3id  PRN BM_ID  Reg_year Reg_collection Reg_no ACQ_method  \
# 0   NaN  NaN   NaN  NaN   NaN       NaN            NaN    NaN        NaN
# 1   NaN  NaN   NaN  NaN   NaN       NaN            NaN    NaN        NaN
# 2   NaN  NaN   NaN  NaN   NaN       NaN            NaN    NaN        NaN
#
#   ACQ_name ACQ_year BibXref Combined_no DIM_H PROV_area PROV_site OBJ_type  \
# 0      NaN      NaN     NaN         NaN   NaN       NaN       NaN      NaN
# 1      NaN      NaN     NaN         NaN   NaN       NaN       NaN      NaN
# 2      NaN      NaN     NaN         NaN   NaN       NaN       NaN      NaN
#
#   Period_culture Script_type_1 Genre Subgenre S_s_genre Language Full_no  \
# 0            NaN           NaN   NaN      NaN       NaN      NaN     NaN
# 1            NaN           NaN   NaN      NaN       NaN      NaN     NaN
# 2            NaN           NaN   NaN      NaN       NaN      NaN     NaN
#
#   DIM_W S_s_s_genre Library_colophon Bib_comment BibSpec PROV_building Ruler  \
# 0   NaN         NaN              NaN         NaN     NaN           NaN   NaN
# 1   NaN         NaN              NaN         NaN     NaN           NaN   NaN
# 2   NaN         NaN              NaN         NaN     NaN           NaN   NaN
#
#   Composition Tablet_number Recension NonLibrary_colophon Reg_part DIM_T  \
# 0         NaN           NaN       NaN                 NaN      NaN   NaN
# 1         NaN           NaN       NaN                 NaN      NaN   NaN
# 2         NaN           NaN       NaN                 NaN      NaN   NaN
#
#   PROV_room Mus_no ACQ_comment Historical_ID Q_no  Day Month Year Emesal  \
# 0       NaN    NaN         NaN           NaN  NaN  NaN   NaN  NaN    NaN
# 1       NaN    NaN         NaN           NaN  NaN  NaN   NaN  NaN    NaN
# 2       NaN    NaN         NaN           NaN  NaN  NaN   NaN  NaN    NaN
#
#   Script_type_2 unique_ID museum_number accession_number sort_order  \
# 0           NaN       NaN           NaN              NaN        NaN
# 1           NaN       NaN           NaN              NaN        NaN
# 2           NaN       NaN           NaN              NaN        NaN
#
#   nme_chapter object findspot museum textname bibliography  \
# 0         NaN    NaN      NaN    NaN      NaN          NaN
# 1         NaN    NaN      NaN    NaN      NaN          NaN
# 2         NaN    NaN      NaN    NaN      NaN          NaN
#
#   Original_collection  DIM_D note Mus_no_part goal_year  seals_number  \
# 0                 NaN    NaN  NaN         NaN       NaN           NaN
# 1                 NaN    NaN  NaN         NaN       NaN           NaN
# 2                 NaN    NaN  NaN         NaN       NaN           NaN
#
#   citation subgenre_remarks published_collation period_remarks  \
# 0      NaN              NaN                 NaN            NaN
# 1      NaN              NaN                 NaN            NaN
# 2      NaN              NaN                 NaN            NaN
#
#    fingernails_number ctn_no nl_no  BAK id_composite person project name  \
# 0                 NaN    NaN   NaN  NaN          NaN    NaN         adsd
# 1                 NaN    NaN   NaN  NaN          NaN    NaN         adsd
# 2                 NaN    NaN   NaN  NaN          NaN    NaN         adsd
#
#   dynastic_seat popular_name text_manu related_comp_id  manu_number  \
# 0           NaN          NaN       NaN             NaN          NaN
# 1           NaN          NaN       NaN             NaN          NaN
# 2           NaN          NaN       NaN             NaN          NaN
#
#   related_manu text_equals_manu text_remarks  has-sources atf_source  \
# 0          NaN              NaN          NaN          NaN        NaN
# 1          NaN              NaN          NaN          NaN        NaN
# 2          NaN              NaN          NaN          NaN        NaN
#
#   date_entered date_updated db_source photo_up translation_source ark_number  \
# 0          NaN          NaN       NaN      NaN                NaN        NaN
# 1          NaN          NaN       NaN      NaN                NaN        NaN
# 2          NaN          NaN       NaN      NaN                NaN        NaN
#
#    id  id_text_int  stt_no seal_id object_preservation object_remarks  \
# 0 NaN          NaN     NaN     NaN                 NaN            NaN
# 1 NaN          NaN     NaN     NaN                 NaN            NaN
# 2 NaN          NaN     NaN     NaN                 NaN            NaN
#
#   exemplars keywords last_modified_by place series status rime_no height  \
# 0       NaN      NaN              NaN   NaN    NaN    NaN     NaN    NaN
# 1       NaN      NaN              NaN   NaN    NaN    NaN     NaN    NaN
# 2       NaN      NaN              NaN   NaN    NaN    NaN     NaN    NaN
#
#   width cdli_composite_id created_by created_on last_modified_on other_names  \
# 0   NaN               NaN        NaN        NaN              NaN         NaN
# 1   NaN               NaN        NaN        NaN              NaN         NaN
# 2   NaN               NaN        NaN        NaN              NaN         NaN
#
#    series_section primary_edition session  pleaides_id date_remarks editor  \
# 0             NaN             NaN     NaN          NaN          NaN    NaN
# 1             NaN             NaN     NaN          NaN          NaN    NaN
# 2             NaN             NaN     NaN          NaN          NaN    NaN
#
#   findspot_remarks  funder  language_remarks lemmed owner  principal  \
# 0              NaN     NaN               NaN    NaN   NaN        NaN
# 1              NaN     NaN               NaN    NaN   NaN        NaN
# 2              NaN     NaN               NaN    NaN   NaN        NaN
#
#    record_id  repository translit_ed uploaded user  bibliography__id_biblio  \
# 0        NaN         NaN         NaN      NaN  NaN                      NaN
# 1        NaN         NaN         NaN      NaN  NaN                      NaN
# 2        NaN         NaN         NaN      NaN  NaN                      NaN
#
#   bibliography__journal_title bibliography__shortref  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
# 2                         NaN                    NaN
#
#   bibliography__volume_number checked photographed photographer proof-read  \
# 0                         NaN     NaN          NaN          NaN        NaN
# 1                         NaN     NaN          NaN          NaN        NaN
# 2                         NaN     NaN          NaN          NaN        NaN
#
#   proof-reader thickness bibliography__book_title pr_joins__pages notes  \
# 0          NaN       NaN                      NaN             NaN   NaN
# 1          NaN       NaN                      NaN             NaN   NaN
# 2          NaN       NaN                      NaN             NaN   NaN
#
#   provenience_remarks  stratigraphic_level join_information  year_name_eponym  \
# 0                 NaN                  NaN              NaN               NaN
# 1                 NaN                  NaN              NaN               NaN
# 2                 NaN                  NaN              NaN               NaN
#
#   distribution sources provdist  CDLI_problems  \
# 0          NaN     NaN      NaN            NaN
# 1          NaN     NaN      NaN            NaN
# 2          NaN     NaN      NaN            NaN
#
#   bibliography__unpublished_title  ark atf_up dates_referenced  \
# 0                             NaN  NaN    NaN              NaN
# 1                             NaN  NaN    NaN              NaN
# 2                             NaN  NaN    NaN              NaN
#
#   surface_preservation composite lineart_up seal_information  \
# 0                  NaN       NaN        NaN              NaN
# 1                  NaN       NaN        NaN              NaN
# 2                  NaN       NaN        NaN              NaN
#
#   google_earth_collection collection_copyright author_remarks cdli_comments  \
# 0                     NaN                  NaN            NaN           NaN
# 1                     NaN                  NaN            NaN           NaN
# 2                     NaN                  NaN            NaN           NaN
#
#   acquisition_history publication ancient_date  has-score last_edited_by  \
# 0                 NaN         NaN          NaN        NaN            NaN
# 1                 NaN         NaN          NaN        NaN            NaN
# 2                 NaN         NaN          NaN        NaN            NaN
#
#   last_edited_on  bdtns_id  reference  Non_Sign_List_Series  series_2  \
# 0            NaN       NaN        NaN                   NaN       NaN
# 1            NaN       NaN        NaN                   NaN       NaN
# 2            NaN       NaN        NaN                   NaN       NaN
#
#    cdli_collation condition_description  tablet_number_2  number  tradition  \
# 0             NaN                   NaN              NaN     NaN        NaN
# 1             NaN                   NaN              NaN     NaN        NaN
# 2             NaN                   NaN              NaN     NaN        NaN
#
#    corpus  attested electronic_publication buy_book  composition_designation  \
# 0     NaN       NaN                    NaN      NaN                      NaN
# 1     NaN       NaN                    NaN      NaN                      NaN
# 2     NaN       NaN                    NaN      NaN                      NaN
#
#    object_ref  lemcount  lemcount_total  lemcount_ave  text_total  lemount_sd  \
# 0         NaN       NaN             NaN           NaN         NaN         NaN
# 1         NaN       NaN             NaN           NaN         NaN         NaN
# 2         NaN       NaN             NaN           NaN         NaN         NaN
#
#   group handcopy pq_joins__external_id qcat_2__id_composite  \
# 0   NaN      NaN                   NaN                  NaN
# 1   NaN      NaN                   NaN                  NaN
# 2   NaN      NaN                   NaN                  NaN
#
#   qcat_2__other_names attribution  new_subgenre  primary_publication2  \
# 0                 NaN         NaN           NaN                   NaN
# 1                 NaN         NaN           NaN                   NaN
# 2                 NaN         NaN           NaN                   NaN
#
#    catchline  colophon_describing_source  colophon_disclosing_author  \
# 0        NaN                         NaN                         NaN
# 1        NaN                         NaN                         NaN
# 2        NaN                         NaN                         NaN
#
#    P_number_problems  royal_colophon  series_tablet_no  textual_colophon  \
# 0                NaN             NaN               NaN               NaN
# 1                NaN             NaN               NaN               NaN
# 2                NaN             NaN               NaN               NaN
#
#    Additional_P_numbers exemplar_info  cdli_id_numbers  composite_id  \
# 0                   NaN           NaN              NaN           NaN
# 1                   NaN           NaN              NaN           NaN
# 2                   NaN           NaN              NaN           NaN
#
#   measurements  elevation  Q_designation  exemplar_number  findspots  \
# 0          NaN        NaN            NaN              NaN        NaN
# 1          NaN        NaN            NaN              NaN        NaN
# 2          NaN        NaN            NaN              NaN        NaN
#
#    btto_attribution  century  outline_sort_name  subproject  \
# 0               NaN      NaN                NaN         NaN
# 1               NaN      NaN                NaN         NaN
# 2               NaN      NaN                NaN         NaN
#
#    modern_converted_date category_oracc place_of_writing_oracc  prosobab  \
# 0                    NaN            NaN                    NaN       NaN
# 1                    NaN            NaN                    NaN       NaN
# 2                    NaN            NaN                    NaN       NaN
#
#   duplicates  copy_period geers_no photo_no ta_photo_no  c_name  c_item  \
# 0        NaN          NaN      NaN      NaN         NaN     NaN     NaN
# 1        NaN          NaN      NaN      NaN         NaN     NaN     NaN
# 2        NaN          NaN      NaN      NaN         NaN     NaN     NaN
#
#    c_both  c_num_name  c_group owner_remarks  special_features  hand columns  \
# 0     NaN         NaN      NaN           NaN               NaN   NaN     NaN
# 1     NaN         NaN      NaN           NaN               NaN   NaN     NaN
# 2     NaN         NaN      NaN           NaN               NaN   NaN     NaN
#
#   headings orientation axes  obta_no type  Delnero_no Delnero_subgenre_no  \
# 0      NaN         NaN  NaN      NaN  NaN         NaN                 NaN
# 1      NaN         NaN  NaN      NaN  NaN         NaN                 NaN
# 2      NaN         NaN  NaN      NaN  NaN         NaN                 NaN
#
#   deity museum_URL Delnero_remarks Cohen_balag  sub_genre external_URL_name  \
# 0   NaN        NaN             NaN         NaN        NaN               NaN
# 1   NaN        NaN             NaN         NaN        NaN               NaN
# 2   NaN        NaN             NaN         NaN        NaN               NaN
#
#   external_URL  additional_P_numbers  ancient_day  ancient_month  \
# 0          NaN                   NaN          NaN            NaN
# 1          NaN                   NaN          NaN            NaN
# 2          NaN                   NaN          NaN            NaN
#
#   google_earth_provenience alternative_years  old_composition_id  \
# 0                      NaN               NaN                 NaN
# 1                      NaN               NaN                 NaN
# 2                      NaN               NaN                 NaN
#
#    accounting_period  Q_objects  Q_places  parallels  new_q  subseries  \
# 0                NaN        NaN       NaN        NaN    NaN        NaN
# 1                NaN        NaN       NaN        NaN    NaN        NaN
# 2                NaN        NaN       NaN        NaN    NaN        NaN
#
#    subseries_section  description oracc_id  sec1  chap  sec2
# 0                NaN          NaN      NaN   NaN   NaN   NaN
# 1                NaN          NaN      NaN   NaN   NaN   NaN
# 2                NaN          NaN      NaN   NaN   NaN   NaN

# %%
#list(megacatalogue.columns)

# %% [markdown]
# Selecting for the columns listed above:

# %%
megacatalogue_short = megacatalogue[[
    'composite_id', 'id_text', 'language', 'material', 'object_type', 'period','provenience','excavation_no','findspot_square','dates_referenced', 'genre', 'subgenre', 'translation_source',
    'archive','collection','museum-nos','mus_no','museum_no','cdli_museum_no','saa_cdli_museum','Mus_no','museum_number','museum','museum_URL',
    'date_of_origin', 'dialect', 'date', 'supergenre', 'xproject','q_number', 'ancient_year', 'date_bce', 'cdli_id', 'OBJ_type',
    'Period_culture', 'Script_type_1', 'Genre', 'Subgenre', 'S_s_genre','Language', 'Full_no', 'Tablet_number', 'Q_no', 'object',
    'id_composite', 'project name', 'id_text_int', 'seal_id','cdli_composite_id', 'ancient_date', 'bdtns_id', 'designation']].dropna(how='all',axis=1)

megacatalogue_short = megacatalogue_short.rename(columns={'id_composite':'composite_id'})
megacatalogue_short
# Out:
#         id_text  language material            object_type          period  \
# 0       P522592  Akkadian     clay                 tablet    Neo-Assyrian
# 1       P522593  Akkadian     clay                 tablet    Neo-Assyrian
# 2       P522594  Akkadian     clay               envelope    Neo-Assyrian
# 3       P522595  Akkadian     clay                 tablet    Neo-Assyrian
# 4       P522596  Akkadian     clay                 tablet    Neo-Assyrian
# ...         ...       ...      ...                    ...             ...
# 171140  P511531  Sumerian      NaN  seal (not impression)  Old Babylonian
# 171141  X201001       NaN      NaN                    NaN         Unknown
# 171142  X201002       NaN      NaN                    NaN         Unknown
# 171143  X225104       NaN      NaN                    NaN         Unknown
# 171144  X423597       NaN      NaN                    NaN         Unknown
#
#                     provenience excavation_no findspot_square  \
# 0       Tell Ahmar (Til Barsip)          T 01             NaN
# 1       Tell Ahmar (Til Barsip)          T 02             NaN
# 2       Tell Ahmar (Til Barsip)          T 03             NaN
# 3       Tell Ahmar (Til Barsip)          T 04             NaN
# 4       Tell Ahmar (Til Barsip)          T 05             NaN
# ...                         ...           ...             ...
# 171140                    Girsu        T 1483             NaN
# 171141                  Unknown           NaN             NaN
# 171142                  Unknown           NaN             NaN
# 171143                  Unknown           NaN             NaN
# 171144                  Unknown           NaN             NaN
#
#        dates_referenced                  genre                subgenre  \
# 0                   NaN  Administrative Record          list (rations)
# 1                   NaN      Legal Transaction               debt note
# 2                   NaN      Legal Transaction                     NaN
# 3                   NaN      Legal Transaction      debt note (silver)
# 4                   NaN      Legal Transaction          sales document
# ...                 ...                    ...                     ...
# 171140              NaN         Administrative  physical cylinder seal
# 171141              NaN                    NaN                     NaN
# 171142              NaN                    NaN                     NaN
# 171143              NaN                    NaN                     NaN
# 171144              NaN                    NaN                     NaN
#
#        translation_source                          archive  \
# 0                     NaN  001 -  Hanni Archive (House C1)
# 1                     NaN  001 -  Hanni Archive (House C1)
# 2                     NaN  001 -  Hanni Archive (House C1)
# 3                     NaN  001 -  Hanni Archive (House C1)
# 4                     NaN  001 -  Hanni Archive (House C1)
# ...                   ...                              ...
# 171140                NaN                              NaN
# 171141                NaN                              NaN
# 171142                NaN                              NaN
# 171143                NaN                              NaN
# 171144                NaN                              NaN
#
#                                      collection museum-nos mus_no museum_no  \
# 0       National Museum of Syria, Aleppo, Syria        NaN    NaN       NaN
# 1       National Museum of Syria, Aleppo, Syria        NaN    NaN       NaN
# 2       National Museum of Syria, Aleppo, Syria        NaN    NaN       NaN
# 3       National Museum of Syria, Aleppo, Syria        NaN    NaN       NaN
# 4       National Museum of Syria, Aleppo, Syria        NaN    NaN       NaN
# ...                                         ...        ...    ...       ...
# 171140                                      NaN        NaN    NaN  AO 16821
# 171141                                      NaN        NaN    NaN       NaN
# 171142                                      NaN        NaN    NaN       NaN
# 171143                                      NaN        NaN    NaN       NaN
# 171144                                      NaN        NaN    NaN       NaN
#
#        cdli_museum_no saa_cdli_museum Mus_no museum_number museum museum_URL  \
# 0                 NaN             NaN    NaN           NaN    NaN        NaN
# 1                 NaN             NaN    NaN           NaN    NaN        NaN
# 2                 NaN             NaN    NaN           NaN    NaN        NaN
# 3                 NaN             NaN    NaN           NaN    NaN        NaN
# 4                 NaN             NaN    NaN           NaN    NaN        NaN
# ...               ...             ...    ...           ...    ...        ...
# 171140            NaN             NaN    NaN           NaN    NaN        NaN
# 171141            NaN             NaN    NaN           NaN    NaN        NaN
# 171142            NaN             NaN    NaN           NaN    NaN        NaN
# 171143            NaN             NaN    NaN           NaN    NaN        NaN
# 171144            NaN             NaN    NaN           NaN    NaN        NaN
#
#                                      date_of_origin       dialect  \
# 0                                      00.000.00.00  Neo-Assyrian
# 1                                      00.000.07.00  Neo-Assyrian
# 2       Assurbanipal.limu Bel-Harran-shaddu’a.07.01  Neo-Assyrian
# 3       Assurbanipal.limu Bel-Harran-shaddu’a.07.01  Neo-Assyrian
# 4                                      00.000.00.00  Neo-Assyrian
# ...                                             ...           ...
# 171140                                          NaN           NaN
# 171141                                          NaN           NaN
# 171142                                          NaN           NaN
# 171143                                          NaN           NaN
# 171144                                          NaN           NaN
#
#                    date supergenre xproject q_number ancient_year date_bce  \
# 0                   NaN        NaN      NaN      NaN          NaN      NaN
# 1       [...]-VII-[...]        NaN      NaN      NaN          NaN      NaN
# 2            650-VII-01        NaN      NaN      NaN          NaN      NaN
# 3            650-VII-01        NaN      NaN      NaN          NaN      NaN
# 4                   NaN        NaN      NaN      NaN          NaN      NaN
# ...                 ...        ...      ...      ...          ...      ...
# 171140              NaN        ELA     CDLI      NaN          NaN      NaN
# 171141              NaN        NaN      NaN      NaN          NaN      NaN
# 171142              NaN        NaN      NaN      NaN          NaN      NaN
# 171143              NaN        NaN      NaN      NaN          NaN      NaN
# 171144              NaN        NaN      NaN      NaN          NaN      NaN
#
#        cdli_id OBJ_type Period_culture Script_type_1 Genre Subgenre S_s_genre  \
# 0          NaN      NaN            NaN           NaN   NaN      NaN       NaN
# 1          NaN      NaN            NaN           NaN   NaN      NaN       NaN
# 2          NaN      NaN            NaN           NaN   NaN      NaN       NaN
# 3          NaN      NaN            NaN           NaN   NaN      NaN       NaN
# 4          NaN      NaN            NaN           NaN   NaN      NaN       NaN
# ...        ...      ...            ...           ...   ...      ...       ...
# 171140     NaN      NaN            NaN           NaN   NaN      NaN       NaN
# 171141     NaN      NaN            NaN           NaN   NaN      NaN       NaN
# 171142     NaN      NaN            NaN           NaN   NaN      NaN       NaN
# 171143     NaN      NaN            NaN           NaN   NaN      NaN       NaN
# 171144     NaN      NaN            NaN           NaN   NaN      NaN       NaN
#
#        Language Full_no Tablet_number Q_no object composite_id  \
# 0           NaN     NaN           NaN  NaN    NaN          NaN
# 1           NaN     NaN           NaN  NaN    NaN          NaN
# 2           NaN     NaN           NaN  NaN    NaN          NaN
# 3           NaN     NaN           NaN  NaN    NaN          NaN
# 4           NaN     NaN           NaN  NaN    NaN          NaN
# ...         ...     ...           ...  ...    ...          ...
# 171140      NaN     NaN           NaN  NaN    NaN          NaN
# 171141      NaN     NaN           NaN  NaN    NaN          NaN
# 171142      NaN     NaN           NaN  NaN    NaN          NaN
# 171143      NaN     NaN           NaN  NaN    NaN          NaN
# 171144      NaN     NaN           NaN  NaN    NaN          NaN
#
#               project name  id_text_int seal_id cdli_composite_id  \
# 0                     adsd          NaN     NaN               NaN
# 1                     adsd          NaN     NaN               NaN
# 2                     adsd          NaN     NaN               NaN
# 3                     adsd          NaN     NaN               NaN
# 4                     adsd          NaN     NaN               NaN
# ...                    ...          ...     ...               ...
# 171140  epsd2/admin/oldbab          NaN     NaN               NaN
# 171141  epsd2/admin/oldbab          NaN     NaN               NaN
# 171142  epsd2/admin/oldbab          NaN     NaN               NaN
# 171143  epsd2/admin/oldbab          NaN     NaN               NaN
# 171144  epsd2/admin/oldbab          NaN     NaN               NaN
#
#        ancient_date  bdtns_id                       designation
# 0               NaN       NaN                     Til-Barsip 01
# 1               NaN       NaN                     Til-Barsip 02
# 2               NaN       NaN                     Til-Barsip 03
# 3               NaN       NaN                     Til-Barsip 04
# 4               NaN       NaN                     Til-Barsip 05
# ...             ...       ...                               ...
# 171140          NaN       NaN  AO 16821 = Parrot, Glyptique 228
# 171141          NaN       NaN                       Iraq 82 129
# 171142          NaN       NaN                       Iraq 82 133
# 171143          NaN       NaN       OB Contracts, pl. D4 no. 24
# 171144          NaN       NaN            www antiquities.fr 004
#
# [171145 rows x 51 columns]

# %% [markdown]
# Exports megacatalogue_short to the folder ORACC_DFS

# %%
megacatalogue_short.to_csv(folder + 'ORACC_DFS/megacatalogue_short.csv')

# %% [markdown]
# #Working with the CDLI catalogue
#
# This section is loosely based off this [notebook](https://drive.google.com/file/d/1yhM_8fgF6p89E3qiH1LRK4EgEau7HLuT/view?usp=sharing).
#
# In this section we will convert the [cdli_cat.csv](https://media.githubusercontent.com/media/cdli-gh/data/master/cdli_cat.csv) into a smaller dataframe called cdli_cat_short that contains only the following useful columns:
#
#     * Language
#     * Material
#     * Museum
#     * Provenience
#     * Object type
#     * Genre
#     * Period
#     * Date
#
# Using this limited version of the cdli catalogue, we can draw comparisons with the oracc data.

# %% [markdown]
# Reading in the data:

# %%
url = 'https://media.githubusercontent.com/media/cdli-gh/data/master/cdli_cat.csv'

data = pd.read_csv(url, sep=',', low_memory=False)
data.head(3)
# Out:
#   accession_no accounting_period acquisition_history alternative_years  \
# 0          NaN               NaN                 NaN               NaN
# 1          NaN               NaN                 NaN               NaN
# 2          NaN               NaN                 NaN               NaN
#
#          ark_number          atf_source atf_up  \
# 0  21198/zz001q0dtm  Englund, Robert K.    NaN
# 1  21198/zz001q0dv4  Englund, Robert K.    NaN
# 2  21198/zz001q0dwn  Englund, Robert K.    NaN
#
#                                  author  \
# 0                                  CDLI
# 1                                  CDLI
# 2  Englund, Robert K. & Nissen, Hans J.
#
#                                       author_remarks cdli_collation  \
# 0  31x61x18; Lú A 14-16.30-32.48-50; M XVIII, auf...            NaN
# 1  30x48x13; Lú A 13-15.23-25.?; Fundstelle wie W...            NaN
# 2  42x53x19; Vocabulary 9; Qa XVI,2, unter der Ab...            NaN
#
#   cdli_comments citation                                 collection  \
# 0           NaN      NaN  Vorderasiatisches Museum, Berlin, Germany
# 1           NaN      NaN  Vorderasiatisches Museum, Berlin, Germany
# 2           NaN      NaN  Vorderasiatisches Museum, Berlin, Germany
#
#   composite_id condition_description date_entered date_of_origin date_remarks  \
# 0      Q000002                   NaN    12/4/2001    00.00.00.00          NaN
# 1      Q000002                   NaN    12/4/2001    00.00.00.00          NaN
# 2          NaN                   NaN    12/4/2001            NaN          NaN
#
#   date_updated dates_referenced                          db_source  \
# 0   2020-03-14      00.00.00.00  20011204 protocuneiform_catalogue
# 1   2018-10-20      00.00.00.00  20011204 protocuneiform_catalogue
# 2   2020-01-26              NaN  20011204 protocuneiform_catalogue
#
#                     designation dumb dumb2 electronic_publication elevation  \
# 0  CDLI Lexical 000002, ex. 065  NaN   NaN                    NaN       NaN
# 1  CDLI Lexical 000002, ex. 066  NaN   NaN                    NaN       NaN
# 2      ATU 3, pl. 081, W 9123,d  NaN   NaN                    NaN       NaN
#
#   excavation_no external_id  \
# 0     W 06435,a         NaN
# 1     W 06435,b         NaN
# 2     W 09123,d         NaN
#
#                                     findspot_remarks findspot_square    genre  \
# 0       auf Hügeloberfläche in der Nähe des Südbaues       M XVIII,?  Lexical
# 1   auf der Hügeloberfläche in der Nähe des Südbaues       M XVIII,?  Lexical
# 2  unter der Abgleichung der Schicht III, 1,5 m ü...        Qa XVI,2  Lexical
#
#   google_earth_collection google_earth_provenience height  id  id_text2  \
# 0                     NaN                      NaN     31   1         0
# 1                     NaN                      NaN     30   2         0
# 2                     NaN                      NaN     42   3         0
#
#    id_text join_information      language       lineart_up material  \
# 0        1              NaN  undetermined  150ppi 20160630     clay
# 1        2              NaN  undetermined  150ppi 20160630     clay
# 2        3              NaN  undetermined  150ppi 20160630     clay
#
#    museum_no object_preservation object_type                       period  \
# 0  VAT 01533                 NaN      tablet  Uruk III (ca. 3200-3000 BC)
# 1  VAT 15263                 NaN      tablet  Uruk III (ca. 3200-3000 BC)
# 2  VAT 15253                 NaN      tablet   Uruk IV (ca. 3350-3200 BC)
#
#   period_remarks photo_up           primary_publication        provenience  \
# 0            NaN      NaN  CDLI Lexical 000002, ex. 065  Uruk (mod. Warka)
# 1            NaN      NaN  CDLI Lexical 000002, ex. 066  Uruk (mod. Warka)
# 2            NaN      NaN      ATU 3, pl. 081, W 9123,d  Uruk (mod. Warka)
#
#   provenience_remarks publication_date  \
# 0                 NaN          2015ff.
# 1                 NaN          2015ff.
# 2                 NaN             1993
#
#                                  publication_history published_collation  \
# 0  Englund, Robert K. & Nissen, Hans J., ATU 3 (1...                 NaN
# 1  Englund, Robert K. & Nissen, Hans J., ATU 3 (1...                 NaN
# 2                                         ATU 1, 539                 NaN
#
#   seal_id seal_information stratigraphic_level                      subgenre  \
# 0     NaN              NaN                 NaN       Archaic Lu2 A (witness)
# 1     NaN              NaN                 NaN       Archaic Lu2 A (witness)
# 2     NaN              NaN                 NaN  Archaic Vocabulary (witness)
#
#                           subgenre_remarks surface_preservation text_remarks  \
# 0                                      NaN                  NaN          NaN
# 1                                      NaN                  NaN          NaN
# 2  Text category: 15-09; Foreign ID: LVO 9                  NaN          NaN
#
#   thickness translation_source width object_remarks
# 0        18     no translation    61            NaN
# 1        13     no translation    48            NaN
# 2        19     no translation    53            NaN

# %% [markdown]
# Create a subset of the cdli catalogue named 'data' with the columns of interest

# %%
#list(data.columns)

# %%
cdli_cat_short = data[['composite_id', 'id_text', 'language', 'object_type', 'period', 'material', 'collection', 'museum_no','provenience', 'excavation_no','findspot_square','date_of_origin',
       'dates_referenced', 'genre', 'subgenre', 'translation_source','designation']].dropna(how='all',axis=1).fillna('')

cdli_cat_short
# Out:
#        composite_id  id_text      language        object_type  \
# 0           Q000002        1  undetermined             tablet
# 1           Q000002        2  undetermined             tablet
# 2                          3  undetermined             tablet
# 3           Q000002        4  undetermined             tablet
# 4           Q000002        5  undetermined             tablet
# ...             ...      ...           ...                ...
# 353278                532443      Sumerian             tablet
# 353279                532444      Akkadian             tablet
# 353280                532445      Akkadian             tablet
# 353281                532446      Akkadian  tablet & envelope
# 353282                532447      Sumerian             tablet
#
#                                    period material  \
# 0             Uruk III (ca. 3200-3000 BC)     clay
# 1             Uruk III (ca. 3200-3000 BC)     clay
# 2              Uruk IV (ca. 3350-3200 BC)     clay
# 3              Uruk IV (ca. 3350-3200 BC)     clay
# 4              Uruk IV (ca. 3350-3200 BC)     clay
# ...                                   ...      ...
# 353278  Old Babylonian (ca. 1900-1600 BC)     clay
# 353279  Old Babylonian (ca. 1900-1600 BC)     clay
# 353280  Old Babylonian (ca. 1900-1600 BC)     clay
# 353281  Old Babylonian (ca. 1900-1600 BC)     clay
# 353282          Ur III (ca. 2100-2000 BC)     clay
#
#                                                collection       museum_no  \
# 0               Vorderasiatisches Museum, Berlin, Germany       VAT 01533
# 1               Vorderasiatisches Museum, Berlin, Germany       VAT 15263
# 2               Vorderasiatisches Museum, Berlin, Germany       VAT 15253
# 3               Vorderasiatisches Museum, Berlin, Germany       VAT 15168
# 4               Vorderasiatisches Museum, Berlin, Germany       VAT 15153
# ...                                                   ...             ...
# 353278             National Museum of Iraq, Baghdad, Iraq            IM —
# 353279             National Museum of Iraq, Baghdad, Iraq            IM —
# 353280             National Museum of Iraq, Baghdad, Iraq            IM —
# 353281  private: William T. Grant Jr., Pelham Manor, N...        Grant 17
# 353282  Harvard Museum of the Ancient Near East, Harva...  SM 1911.10.379
#
#                           provenience excavation_no findspot_square  \
# 0                   Uruk (mod. Warka)     W 06435,a       M XVIII,?
# 1                   Uruk (mod. Warka)     W 06435,b       M XVIII,?
# 2                   Uruk (mod. Warka)     W 09123,d        Qa XVI,2
# 3                   Uruk (mod. Warka)     W 09169,d        Qa XVI,2
# 4                   Uruk (mod. Warka)     W 09206,k        Qa XVI,2
# ...                               ...           ...             ...
# 353278    Marad (mod. Wanna-wa-Sadum)     Marad 047
# 353279                                      TA 2100
# 353280                                      TA 2101
# 353281  Larsa (mod. Tell as-Senkereh)
# 353282     Puzriš-Dagan (mod. Drehem)
#
#             date_of_origin    dates_referenced           genre  \
# 0              00.00.00.00         00.00.00.00         Lexical
# 1              00.00.00.00         00.00.00.00         Lexical
# 2                                                      Lexical
# 3              00.00.00.00         00.00.00.00         Lexical
# 4              00.00.00.00         00.00.00.00         Lexical
# ...                    ...                 ...             ...
# 353278                                                   Legal
# 353279                                          Administrative
# 353280                                          Administrative
# 353281                                                   Legal
# 353282  Amar-Suen.08.08.10  Amar-Suen.08.08.10  Administrative
#
#                             subgenre translation_source  \
# 0            Archaic Lu2 A (witness)     no translation
# 1            Archaic Lu2 A (witness)     no translation
# 2       Archaic Vocabulary (witness)     no translation
# 3            Archaic Lu2 A (witness)     no translation
# 4            Archaic Lu2 A (witness)     no translation
# ...                              ...                ...
# 353278                                   no translation
# 353279                                   no translation
# 353280                                   no translation
# 353281                                   no translation
# 353282                                   no translation
#
#                                  designation
# 0               CDLI Lexical 000002, ex. 065
# 1               CDLI Lexical 000002, ex. 066
# 2                   ATU 3, pl. 081, W 9123,d
# 3               CDLI Lexical 000002, ex. 051
# 4               CDLI Lexical 000002, ex. 172
# ...                                      ...
# 353278      Adab Al-Rafidayn 63, 83-92 no. 2
# 353279  Iraq 35, 173-175 (pl. 71-72) TA 2100
# 353280  Iraq 35, 173-175 (pl. 71-72) TA 2101
# 353281                      AJSL 34, 199-204
# 353282                           HSS 68, 433
#
# [353283 rows x 17 columns]

# %% [markdown]
# Exports cdli_cat_short to the folder ORACC_DFS

# %%
cdli_cat_short.to_csv(folder + 'ORACC_DFS/cdli_cat_short.csv')

# %% [markdown]
# #Creating the Metacatalogue
#
# Using the CDLI shortened catalogue and the ORACC shortened catalogue, we can create a Metacatalogue- a combination of both catalogues.

# %% [markdown]
# The following codecell allows for importing the megacatalogue short and cdli cat short to run the following cells independently of the first half of this notebook.

# %%
#cshortpath = '/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_DFS/cdli_cat_short.csv'
#mshortpath = '/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_DFS/megacatalogue_short.csv'
cshortpath = folder + 'ORACC_DFS/cdli_cat_short.csv'
mshortpath = folder + 'ORACC_DFS/megacatalogue_short.csv'
cdli_cat_short = pd.read_csv(cshortpath, low_memory=False, index_col=0)
megacatalogue_short = pd.read_csv(mshortpath, low_memory=False, index_col=0)

# %%
print(cdli_cat_short.shape)
cdli_cat_short.head(3)
# Out:
# (353283, 17)
#   composite_id  id_text      language object_type  \
# 0      Q000002        1  undetermined      tablet
# 1      Q000002        2  undetermined      tablet
# 2          NaN        3  undetermined      tablet
#
#                         period material  \
# 0  Uruk III (ca. 3200-3000 BC)     clay
# 1  Uruk III (ca. 3200-3000 BC)     clay
# 2   Uruk IV (ca. 3350-3200 BC)     clay
#
#                                   collection  museum_no        provenience  \
# 0  Vorderasiatisches Museum, Berlin, Germany  VAT 01533  Uruk (mod. Warka)
# 1  Vorderasiatisches Museum, Berlin, Germany  VAT 15263  Uruk (mod. Warka)
# 2  Vorderasiatisches Museum, Berlin, Germany  VAT 15253  Uruk (mod. Warka)
#
#   excavation_no findspot_square date_of_origin dates_referenced    genre  \
# 0     W 06435,a       M XVIII,?    00.00.00.00      00.00.00.00  Lexical
# 1     W 06435,b       M XVIII,?    00.00.00.00      00.00.00.00  Lexical
# 2     W 09123,d        Qa XVI,2            NaN              NaN  Lexical
#
#                        subgenre translation_source  \
# 0       Archaic Lu2 A (witness)     no translation
# 1       Archaic Lu2 A (witness)     no translation
# 2  Archaic Vocabulary (witness)     no translation
#
#                     designation
# 0  CDLI Lexical 000002, ex. 065
# 1  CDLI Lexical 000002, ex. 066
# 2      ATU 3, pl. 081, W 9123,d

# %% [markdown]
# Changing the column 'id_text' to be in the form P+6 numbers in order to match with the ORACC ids

# %%
cdli_cat_short['id_text'] = ['P'+str(id).zfill(6) for id in cdli_cat_short['id_text']]
cdli_cat_short.head(3)
# Out:
#   composite_id  id_text      language object_type  \
# 0      Q000002  P000001  undetermined      tablet
# 1      Q000002  P000002  undetermined      tablet
# 2          NaN  P000003  undetermined      tablet
#
#                         period material  \
# 0  Uruk III (ca. 3200-3000 BC)     clay
# 1  Uruk III (ca. 3200-3000 BC)     clay
# 2   Uruk IV (ca. 3350-3200 BC)     clay
#
#                                   collection  museum_no        provenience  \
# 0  Vorderasiatisches Museum, Berlin, Germany  VAT 01533  Uruk (mod. Warka)
# 1  Vorderasiatisches Museum, Berlin, Germany  VAT 15263  Uruk (mod. Warka)
# 2  Vorderasiatisches Museum, Berlin, Germany  VAT 15253  Uruk (mod. Warka)
#
#   excavation_no findspot_square date_of_origin dates_referenced    genre  \
# 0     W 06435,a       M XVIII,?    00.00.00.00      00.00.00.00  Lexical
# 1     W 06435,b       M XVIII,?    00.00.00.00      00.00.00.00  Lexical
# 2     W 09123,d        Qa XVI,2            NaN              NaN  Lexical
#
#                        subgenre translation_source  \
# 0       Archaic Lu2 A (witness)     no translation
# 1       Archaic Lu2 A (witness)     no translation
# 2  Archaic Vocabulary (witness)     no translation
#
#                     designation
# 0  CDLI Lexical 000002, ex. 065
# 1  CDLI Lexical 000002, ex. 066
# 2      ATU 3, pl. 081, W 9123,d

# %%
print(megacatalogue_short.shape)
megacatalogue_short.head(3)
# Out:
# (171145, 51)
#    id_text  language material object_type        period  \
# 0  P522592  Akkadian     clay      tablet  Neo-Assyrian
# 1  P522593  Akkadian     clay      tablet  Neo-Assyrian
# 2  P522594  Akkadian     clay    envelope  Neo-Assyrian
#
#                provenience excavation_no findspot_square dates_referenced  \
# 0  Tell Ahmar (Til Barsip)          T 01             NaN              NaN
# 1  Tell Ahmar (Til Barsip)          T 02             NaN              NaN
# 2  Tell Ahmar (Til Barsip)          T 03             NaN              NaN
#
#                    genre        subgenre translation_source  \
# 0  Administrative Record  list (rations)                NaN
# 1      Legal Transaction       debt note                NaN
# 2      Legal Transaction             NaN                NaN
#
#                            archive                               collection  \
# 0  001 -  Hanni Archive (House C1)  National Museum of Syria, Aleppo, Syria
# 1  001 -  Hanni Archive (House C1)  National Museum of Syria, Aleppo, Syria
# 2  001 -  Hanni Archive (House C1)  National Museum of Syria, Aleppo, Syria
#
#   museum-nos mus_no museum_no cdli_museum_no saa_cdli_museum Mus_no  \
# 0        NaN    NaN       NaN            NaN             NaN    NaN
# 1        NaN    NaN       NaN            NaN             NaN    NaN
# 2        NaN    NaN       NaN            NaN             NaN    NaN
#
#   museum_number museum museum_URL  \
# 0           NaN    NaN        NaN
# 1           NaN    NaN        NaN
# 2           NaN    NaN        NaN
#
#                                 date_of_origin       dialect             date  \
# 0                                 00.000.00.00  Neo-Assyrian              NaN
# 1                                 00.000.07.00  Neo-Assyrian  [...]-VII-[...]
# 2  Assurbanipal.limu Bel-Harran-shaddu’a.07.01  Neo-Assyrian       650-VII-01
#
#   supergenre xproject q_number ancient_year date_bce cdli_id OBJ_type  \
# 0        NaN      NaN      NaN          NaN      NaN     NaN      NaN
# 1        NaN      NaN      NaN          NaN      NaN     NaN      NaN
# 2        NaN      NaN      NaN          NaN      NaN     NaN      NaN
#
#   Period_culture Script_type_1 Genre Subgenre S_s_genre Language Full_no  \
# 0            NaN           NaN   NaN      NaN       NaN      NaN     NaN
# 1            NaN           NaN   NaN      NaN       NaN      NaN     NaN
# 2            NaN           NaN   NaN      NaN       NaN      NaN     NaN
#
#   Tablet_number Q_no object composite_id project name  id_text_int seal_id  \
# 0           NaN  NaN    NaN          NaN         adsd          NaN     NaN
# 1           NaN  NaN    NaN          NaN         adsd          NaN     NaN
# 2           NaN  NaN    NaN          NaN         adsd          NaN     NaN
#
#   cdli_composite_id ancient_date  bdtns_id    designation
# 0               NaN          NaN       NaN  Til-Barsip 01
# 1               NaN          NaN       NaN  Til-Barsip 02
# 2               NaN          NaN       NaN  Til-Barsip 03

# %% [markdown]
# Creation of the Metacatalogue
#
# This dataframe merges the cdli_cat_short and megacatalogue_short DFs based on the "id_text" column. It contains the rows where id_text matches and doesnt match. Any column marked as column_x belongs to the CDLI catalogue and any column marked as column_y belongs to the ORACC catalogue.
#
# Note

# %%
metacatalogue = pd.merge(cdli_cat_short, megacatalogue_short, on="id_text", how = 'outer')
metacatalogue
# Out:
#        composite_id_x  id_text    language_x object_type_x  \
# 0             Q000002  P000001  undetermined        tablet
# 1             Q000002  P000002  undetermined        tablet
# 2                 NaN  P000003  undetermined        tablet
# 3             Q000002  P000004  undetermined        tablet
# 4             Q000002  P000005  undetermined        tablet
# ...               ...      ...           ...           ...
# 366911            NaN  X096677           NaN           NaN
# 366912            NaN  X201001           NaN           NaN
# 366913            NaN  X201002           NaN           NaN
# 366914            NaN  X225104           NaN           NaN
# 366915            NaN  X423597           NaN           NaN
#
#                            period_x material_x  \
# 0       Uruk III (ca. 3200-3000 BC)       clay
# 1       Uruk III (ca. 3200-3000 BC)       clay
# 2        Uruk IV (ca. 3350-3200 BC)       clay
# 3        Uruk IV (ca. 3350-3200 BC)       clay
# 4        Uruk IV (ca. 3350-3200 BC)       clay
# ...                             ...        ...
# 366911                          NaN        NaN
# 366912                          NaN        NaN
# 366913                          NaN        NaN
# 366914                          NaN        NaN
# 366915                          NaN        NaN
#
#                                      collection_x museum_no_x  \
# 0       Vorderasiatisches Museum, Berlin, Germany   VAT 01533
# 1       Vorderasiatisches Museum, Berlin, Germany   VAT 15263
# 2       Vorderasiatisches Museum, Berlin, Germany   VAT 15253
# 3       Vorderasiatisches Museum, Berlin, Germany   VAT 15168
# 4       Vorderasiatisches Museum, Berlin, Germany   VAT 15153
# ...                                           ...         ...
# 366911                                        NaN         NaN
# 366912                                        NaN         NaN
# 366913                                        NaN         NaN
# 366914                                        NaN         NaN
# 366915                                        NaN         NaN
#
#             provenience_x excavation_no_x findspot_square_x date_of_origin_x  \
# 0       Uruk (mod. Warka)       W 06435,a         M XVIII,?      00.00.00.00
# 1       Uruk (mod. Warka)       W 06435,b         M XVIII,?      00.00.00.00
# 2       Uruk (mod. Warka)       W 09123,d          Qa XVI,2              NaN
# 3       Uruk (mod. Warka)       W 09169,d          Qa XVI,2      00.00.00.00
# 4       Uruk (mod. Warka)       W 09206,k          Qa XVI,2      00.00.00.00
# ...                   ...             ...               ...              ...
# 366911                NaN             NaN               NaN              NaN
# 366912                NaN             NaN               NaN              NaN
# 366913                NaN             NaN               NaN              NaN
# 366914                NaN             NaN               NaN              NaN
# 366915                NaN             NaN               NaN              NaN
#
#        dates_referenced_x  genre_x                    subgenre_x  \
# 0             00.00.00.00  Lexical       Archaic Lu2 A (witness)
# 1             00.00.00.00  Lexical       Archaic Lu2 A (witness)
# 2                     NaN  Lexical  Archaic Vocabulary (witness)
# 3             00.00.00.00  Lexical       Archaic Lu2 A (witness)
# 4             00.00.00.00  Lexical       Archaic Lu2 A (witness)
# ...                   ...      ...                           ...
# 366911                NaN      NaN                           NaN
# 366912                NaN      NaN                           NaN
# 366913                NaN      NaN                           NaN
# 366914                NaN      NaN                           NaN
# 366915                NaN      NaN                           NaN
#
#        translation_source_x                 designation_x    language_y  \
# 0            no translation  CDLI Lexical 000002, ex. 065  undetermined
# 1            no translation  CDLI Lexical 000002, ex. 066  undetermined
# 2            no translation      ATU 3, pl. 081, W 9123,d  undetermined
# 3            no translation  CDLI Lexical 000002, ex. 051  undetermined
# 4            no translation  CDLI Lexical 000002, ex. 172  undetermined
# ...                     ...                           ...           ...
# 366911                  NaN                           NaN           NaN
# 366912                  NaN                           NaN           NaN
# 366913                  NaN                           NaN           NaN
# 366914                  NaN                           NaN           NaN
# 366915                  NaN                           NaN           NaN
#
#        material_y object_type_y  period_y provenience_y excavation_no_y  \
# 0            clay        tablet  Uruk III  Warka (Uruk)             NaN
# 1            clay        tablet  Uruk III  Warka (Uruk)             NaN
# 2            clay        tablet   Uruk IV  Warka (Uruk)             NaN
# 3            clay        tablet   Uruk IV  Warka (Uruk)             NaN
# 4            clay        tablet   Uruk IV  Warka (Uruk)             NaN
# ...           ...           ...       ...           ...             ...
# 366911        NaN           NaN   Unknown       Unknown             NaN
# 366912        NaN           NaN   Unknown       Unknown             NaN
# 366913        NaN           NaN   Unknown       Unknown             NaN
# 366914        NaN           NaN   Unknown       Unknown             NaN
# 366915        NaN           NaN   Unknown       Unknown             NaN
#
#        findspot_square_y dates_referenced_y  genre_y subgenre_y  \
# 0                    NaN                NaN  Lexical        NaN
# 1                    NaN                NaN  Lexical        NaN
# 2                    NaN                NaN  Lexical        NaN
# 3                    NaN                NaN  Lexical        NaN
# 4                    NaN                NaN  Lexical        NaN
# ...                  ...                ...      ...        ...
# 366911               NaN                NaN      NaN        NaN
# 366912               NaN                NaN      NaN        NaN
# 366913               NaN                NaN      NaN        NaN
# 366914               NaN                NaN      NaN        NaN
# 366915               NaN                NaN      NaN        NaN
#
#        translation_source_y archive  \
# 0                       NaN     NaN
# 1                       NaN     NaN
# 2                       NaN     NaN
# 3                       NaN     NaN
# 4                       NaN     NaN
# ...                     ...     ...
# 366911                  NaN     NaN
# 366912                  NaN     NaN
# 366913                  NaN     NaN
# 366914                  NaN     NaN
# 366915                  NaN     NaN
#
#                                      collection_y museum-nos mus_no  \
# 0       Vorderasiatisches Museum, Berlin, Germany        NaN    NaN
# 1       Vorderasiatisches Museum, Berlin, Germany        NaN    NaN
# 2       Vorderasiatisches Museum, Berlin, Germany        NaN    NaN
# 3       Vorderasiatisches Museum, Berlin, Germany        NaN    NaN
# 4       Vorderasiatisches Museum, Berlin, Germany        NaN    NaN
# ...                                           ...        ...    ...
# 366911                                        NaN        NaN    NaN
# 366912                                        NaN        NaN    NaN
# 366913                                        NaN        NaN    NaN
# 366914                                        NaN        NaN    NaN
# 366915                                        NaN        NaN    NaN
#
#        museum_no_y cdli_museum_no saa_cdli_museum Mus_no museum_number museum  \
# 0              NaN            NaN             NaN    NaN           NaN    NaN
# 1              NaN            NaN             NaN    NaN           NaN    NaN
# 2              NaN            NaN             NaN    NaN           NaN    NaN
# 3              NaN            NaN             NaN    NaN           NaN    NaN
# 4              NaN            NaN             NaN    NaN           NaN    NaN
# ...            ...            ...             ...    ...           ...    ...
# 366911         NaN            NaN             NaN    NaN           NaN    NaN
# 366912         NaN            NaN             NaN    NaN           NaN    NaN
# 366913         NaN            NaN             NaN    NaN           NaN    NaN
# 366914         NaN            NaN             NaN    NaN           NaN    NaN
# 366915         NaN            NaN             NaN    NaN           NaN    NaN
#
#        museum_URL date_of_origin_y dialect date supergenre xproject q_number  \
# 0             NaN              NaN     NaN  NaN        LEX     CDLI      NaN
# 1             NaN              NaN     NaN  NaN        LEX     CDLI      NaN
# 2             NaN              NaN     NaN  NaN        LEX     CDLI      NaN
# 3             NaN              NaN     NaN  NaN        LEX     CDLI      NaN
# 4             NaN              NaN     NaN  NaN        LEX     CDLI      NaN
# ...           ...              ...     ...  ...        ...      ...      ...
# 366911        NaN              NaN     NaN  NaN        NaN      NaN      NaN
# 366912        NaN              NaN     NaN  NaN        NaN      NaN      NaN
# 366913        NaN              NaN     NaN  NaN        NaN      NaN      NaN
# 366914        NaN              NaN     NaN  NaN        NaN      NaN      NaN
# 366915        NaN              NaN     NaN  NaN        NaN      NaN      NaN
#
#        ancient_year date_bce  cdli_id OBJ_type Period_culture Script_type_1  \
# 0               NaN      NaN  P000001      NaN            NaN           NaN
# 1               NaN      NaN  P000002      NaN            NaN           NaN
# 2               NaN      NaN  P000003      NaN            NaN           NaN
# 3               NaN      NaN  P000004      NaN            NaN           NaN
# 4               NaN      NaN  P000005      NaN            NaN           NaN
# ...             ...      ...      ...      ...            ...           ...
# 366911          NaN      NaN      NaN      NaN            NaN           NaN
# 366912          NaN      NaN      NaN      NaN            NaN           NaN
# 366913          NaN      NaN      NaN      NaN            NaN           NaN
# 366914          NaN      NaN      NaN      NaN            NaN           NaN
# 366915          NaN      NaN      NaN      NaN            NaN           NaN
#
#        Genre Subgenre S_s_genre Language Full_no Tablet_number Q_no object  \
# 0        NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# 1        NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# 2        NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# 3        NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# 4        NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# ...      ...      ...       ...      ...     ...           ...  ...    ...
# 366911   NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# 366912   NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# 366913   NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# 366914   NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# 366915   NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
#
#        composite_id_y        project name  id_text_int seal_id  \
# 0                 NaN               armep          NaN     NaN
# 1                 NaN               armep          NaN     NaN
# 2                 NaN               armep          NaN     NaN
# 3                 NaN               armep          NaN     NaN
# 4                 NaN               armep          NaN     NaN
# ...               ...                 ...          ...     ...
# 366911            NaN      epsd2/earlylit          NaN     NaN
# 366912            NaN  epsd2/admin/oldbab          NaN     NaN
# 366913            NaN  epsd2/admin/oldbab          NaN     NaN
# 366914            NaN  epsd2/admin/oldbab          NaN     NaN
# 366915            NaN  epsd2/admin/oldbab          NaN     NaN
#
#        cdli_composite_id ancient_date  bdtns_id                designation_y
# 0                    NaN          NaN       NaN                    W 06435,a
# 1                    NaN          NaN       NaN                    W 06435,b
# 2                    NaN          NaN       NaN                    W 09123,d
# 3                    NaN          NaN       NaN                    W 09169,d
# 4                    NaN          NaN       NaN                    W 09206,k
# ...                  ...          ...       ...                          ...
# 366911               NaN          NaN       NaN                    BM 096677
# 366912               NaN          NaN       NaN                  Iraq 82 129
# 366913               NaN          NaN       NaN                  Iraq 82 133
# 366914               NaN          NaN       NaN  OB Contracts, pl. D4 no. 24
# 366915               NaN          NaN       NaN       www antiquities.fr 004
#
# [366916 rows x 67 columns]

# %% [markdown]
# Export the metacatalogue

# %%
metacatalogue.to_csv(folder + 'ORACC_DFS/metacatalogue.csv')

# %% [markdown]
# ##Comparisons between matching CDLI and ORACC headers
#
# One thing we can do is to place like-columns from each dataframe side by side. By reformatting the metacatalogue in this way, it may make columns easier to compare at a glance.

# %%
metacatalogue_sorted = metacatalogue[['id_text','composite_id_x', 'composite_id_y', 'language_x', 'language_y', 'material_x', 'material_y', 'object_type_x', 'object_type_y',
    'period_x', 'period_y', 'dates_referenced_x', 'dates_referenced_y', 'genre_x', 'genre_y', 'subgenre_x', 'subgenre_y', 'translation_source_x', 'translation_source_y', 'provenience_x','provenience_y','excavation_no_x','excavation_no_y','findspot_square_x','findspot_square_y',
    'date_of_origin_x', 'date_of_origin_y','museum_no_x','museum_no_y','collection_x','collection_y','dialect', 'date', 'supergenre', 'xproject','q_number', 'ancient_year', 'date_bce', 'cdli_id', 'OBJ_type',
    'designation_x','designation_y','Period_culture', 'Script_type_1', 'Genre', 'Subgenre', 'S_s_genre','Language', 'Full_no', 'Tablet_number', 'Q_no', 'object',
    'project name', 'id_text_int', 'seal_id','cdli_composite_id', 'ancient_date', 'bdtns_id']]

#print(metacatalogue_sorted.shape)
metacatalogue_sorted
# Out:
#         id_text composite_id_x composite_id_y    language_x    language_y  \
# 0       P000001        Q000002            NaN  undetermined  undetermined
# 1       P000002        Q000002            NaN  undetermined  undetermined
# 2       P000003            NaN            NaN  undetermined  undetermined
# 3       P000004        Q000002            NaN  undetermined  undetermined
# 4       P000005        Q000002            NaN  undetermined  undetermined
# ...         ...            ...            ...           ...           ...
# 366911  X096677            NaN            NaN           NaN           NaN
# 366912  X201001            NaN            NaN           NaN           NaN
# 366913  X201002            NaN            NaN           NaN           NaN
# 366914  X225104            NaN            NaN           NaN           NaN
# 366915  X423597            NaN            NaN           NaN           NaN
#
#        material_x material_y object_type_x object_type_y  \
# 0            clay       clay        tablet        tablet
# 1            clay       clay        tablet        tablet
# 2            clay       clay        tablet        tablet
# 3            clay       clay        tablet        tablet
# 4            clay       clay        tablet        tablet
# ...           ...        ...           ...           ...
# 366911        NaN        NaN           NaN           NaN
# 366912        NaN        NaN           NaN           NaN
# 366913        NaN        NaN           NaN           NaN
# 366914        NaN        NaN           NaN           NaN
# 366915        NaN        NaN           NaN           NaN
#
#                            period_x  period_y dates_referenced_x  \
# 0       Uruk III (ca. 3200-3000 BC)  Uruk III        00.00.00.00
# 1       Uruk III (ca. 3200-3000 BC)  Uruk III        00.00.00.00
# 2        Uruk IV (ca. 3350-3200 BC)   Uruk IV                NaN
# 3        Uruk IV (ca. 3350-3200 BC)   Uruk IV        00.00.00.00
# 4        Uruk IV (ca. 3350-3200 BC)   Uruk IV        00.00.00.00
# ...                             ...       ...                ...
# 366911                          NaN   Unknown                NaN
# 366912                          NaN   Unknown                NaN
# 366913                          NaN   Unknown                NaN
# 366914                          NaN   Unknown                NaN
# 366915                          NaN   Unknown                NaN
#
#        dates_referenced_y  genre_x  genre_y                    subgenre_x  \
# 0                     NaN  Lexical  Lexical       Archaic Lu2 A (witness)
# 1                     NaN  Lexical  Lexical       Archaic Lu2 A (witness)
# 2                     NaN  Lexical  Lexical  Archaic Vocabulary (witness)
# 3                     NaN  Lexical  Lexical       Archaic Lu2 A (witness)
# 4                     NaN  Lexical  Lexical       Archaic Lu2 A (witness)
# ...                   ...      ...      ...                           ...
# 366911                NaN      NaN      NaN                           NaN
# 366912                NaN      NaN      NaN                           NaN
# 366913                NaN      NaN      NaN                           NaN
# 366914                NaN      NaN      NaN                           NaN
# 366915                NaN      NaN      NaN                           NaN
#
#        subgenre_y translation_source_x translation_source_y  \
# 0             NaN       no translation                  NaN
# 1             NaN       no translation                  NaN
# 2             NaN       no translation                  NaN
# 3             NaN       no translation                  NaN
# 4             NaN       no translation                  NaN
# ...           ...                  ...                  ...
# 366911        NaN                  NaN                  NaN
# 366912        NaN                  NaN                  NaN
# 366913        NaN                  NaN                  NaN
# 366914        NaN                  NaN                  NaN
# 366915        NaN                  NaN                  NaN
#
#             provenience_x provenience_y excavation_no_x excavation_no_y  \
# 0       Uruk (mod. Warka)  Warka (Uruk)       W 06435,a             NaN
# 1       Uruk (mod. Warka)  Warka (Uruk)       W 06435,b             NaN
# 2       Uruk (mod. Warka)  Warka (Uruk)       W 09123,d             NaN
# 3       Uruk (mod. Warka)  Warka (Uruk)       W 09169,d             NaN
# 4       Uruk (mod. Warka)  Warka (Uruk)       W 09206,k             NaN
# ...                   ...           ...             ...             ...
# 366911                NaN       Unknown             NaN             NaN
# 366912                NaN       Unknown             NaN             NaN
# 366913                NaN       Unknown             NaN             NaN
# 366914                NaN       Unknown             NaN             NaN
# 366915                NaN       Unknown             NaN             NaN
#
#        findspot_square_x findspot_square_y date_of_origin_x date_of_origin_y  \
# 0              M XVIII,?               NaN      00.00.00.00              NaN
# 1              M XVIII,?               NaN      00.00.00.00              NaN
# 2               Qa XVI,2               NaN              NaN              NaN
# 3               Qa XVI,2               NaN      00.00.00.00              NaN
# 4               Qa XVI,2               NaN      00.00.00.00              NaN
# ...                  ...               ...              ...              ...
# 366911               NaN               NaN              NaN              NaN
# 366912               NaN               NaN              NaN              NaN
# 366913               NaN               NaN              NaN              NaN
# 366914               NaN               NaN              NaN              NaN
# 366915               NaN               NaN              NaN              NaN
#
#        museum_no_x museum_no_y                               collection_x  \
# 0        VAT 01533         NaN  Vorderasiatisches Museum, Berlin, Germany
# 1        VAT 15263         NaN  Vorderasiatisches Museum, Berlin, Germany
# 2        VAT 15253         NaN  Vorderasiatisches Museum, Berlin, Germany
# 3        VAT 15168         NaN  Vorderasiatisches Museum, Berlin, Germany
# 4        VAT 15153         NaN  Vorderasiatisches Museum, Berlin, Germany
# ...            ...         ...                                        ...
# 366911         NaN         NaN                                        NaN
# 366912         NaN         NaN                                        NaN
# 366913         NaN         NaN                                        NaN
# 366914         NaN         NaN                                        NaN
# 366915         NaN         NaN                                        NaN
#
#                                      collection_y dialect date supergenre  \
# 0       Vorderasiatisches Museum, Berlin, Germany     NaN  NaN        LEX
# 1       Vorderasiatisches Museum, Berlin, Germany     NaN  NaN        LEX
# 2       Vorderasiatisches Museum, Berlin, Germany     NaN  NaN        LEX
# 3       Vorderasiatisches Museum, Berlin, Germany     NaN  NaN        LEX
# 4       Vorderasiatisches Museum, Berlin, Germany     NaN  NaN        LEX
# ...                                           ...     ...  ...        ...
# 366911                                        NaN     NaN  NaN        NaN
# 366912                                        NaN     NaN  NaN        NaN
# 366913                                        NaN     NaN  NaN        NaN
# 366914                                        NaN     NaN  NaN        NaN
# 366915                                        NaN     NaN  NaN        NaN
#
#        xproject q_number ancient_year date_bce  cdli_id OBJ_type  \
# 0          CDLI      NaN          NaN      NaN  P000001      NaN
# 1          CDLI      NaN          NaN      NaN  P000002      NaN
# 2          CDLI      NaN          NaN      NaN  P000003      NaN
# 3          CDLI      NaN          NaN      NaN  P000004      NaN
# 4          CDLI      NaN          NaN      NaN  P000005      NaN
# ...         ...      ...          ...      ...      ...      ...
# 366911      NaN      NaN          NaN      NaN      NaN      NaN
# 366912      NaN      NaN          NaN      NaN      NaN      NaN
# 366913      NaN      NaN          NaN      NaN      NaN      NaN
# 366914      NaN      NaN          NaN      NaN      NaN      NaN
# 366915      NaN      NaN          NaN      NaN      NaN      NaN
#
#                        designation_x                designation_y  \
# 0       CDLI Lexical 000002, ex. 065                    W 06435,a
# 1       CDLI Lexical 000002, ex. 066                    W 06435,b
# 2           ATU 3, pl. 081, W 9123,d                    W 09123,d
# 3       CDLI Lexical 000002, ex. 051                    W 09169,d
# 4       CDLI Lexical 000002, ex. 172                    W 09206,k
# ...                              ...                          ...
# 366911                           NaN                    BM 096677
# 366912                           NaN                  Iraq 82 129
# 366913                           NaN                  Iraq 82 133
# 366914                           NaN  OB Contracts, pl. D4 no. 24
# 366915                           NaN       www antiquities.fr 004
#
#        Period_culture Script_type_1 Genre Subgenre S_s_genre Language Full_no  \
# 0                 NaN           NaN   NaN      NaN       NaN      NaN     NaN
# 1                 NaN           NaN   NaN      NaN       NaN      NaN     NaN
# 2                 NaN           NaN   NaN      NaN       NaN      NaN     NaN
# 3                 NaN           NaN   NaN      NaN       NaN      NaN     NaN
# 4                 NaN           NaN   NaN      NaN       NaN      NaN     NaN
# ...               ...           ...   ...      ...       ...      ...     ...
# 366911            NaN           NaN   NaN      NaN       NaN      NaN     NaN
# 366912            NaN           NaN   NaN      NaN       NaN      NaN     NaN
# 366913            NaN           NaN   NaN      NaN       NaN      NaN     NaN
# 366914            NaN           NaN   NaN      NaN       NaN      NaN     NaN
# 366915            NaN           NaN   NaN      NaN       NaN      NaN     NaN
#
#        Tablet_number Q_no object        project name  id_text_int seal_id  \
# 0                NaN  NaN    NaN               armep          NaN     NaN
# 1                NaN  NaN    NaN               armep          NaN     NaN
# 2                NaN  NaN    NaN               armep          NaN     NaN
# 3                NaN  NaN    NaN               armep          NaN     NaN
# 4                NaN  NaN    NaN               armep          NaN     NaN
# ...              ...  ...    ...                 ...          ...     ...
# 366911           NaN  NaN    NaN      epsd2/earlylit          NaN     NaN
# 366912           NaN  NaN    NaN  epsd2/admin/oldbab          NaN     NaN
# 366913           NaN  NaN    NaN  epsd2/admin/oldbab          NaN     NaN
# 366914           NaN  NaN    NaN  epsd2/admin/oldbab          NaN     NaN
# 366915           NaN  NaN    NaN  epsd2/admin/oldbab          NaN     NaN
#
#        cdli_composite_id ancient_date  bdtns_id
# 0                    NaN          NaN       NaN
# 1                    NaN          NaN       NaN
# 2                    NaN          NaN       NaN
# 3                    NaN          NaN       NaN
# 4                    NaN          NaN       NaN
# ...                  ...          ...       ...
# 366911               NaN          NaN       NaN
# 366912               NaN          NaN       NaN
# 366913               NaN          NaN       NaN
# 366914               NaN          NaN       NaN
# 366915               NaN          NaN       NaN
#
# [366916 rows x 58 columns]

# %%
for i in ['composite_id', 'language', 'material', 'object_type', 'period','dates_referenced', 'genre', 'subgenre', 'translation_source', 'provenience','excavation_no','findspot_square','date_of_origin','museum_no','collection','designation']:
   print(i + ' has ' + str((metacatalogue[i+'_x'] == metacatalogue[i+'_y']).sum()) + ' matches.')
# Out:
# composite_id has 0 matches.
# language has 118158 matches.
# material has 38616 matches.
# object_type has 55576 matches.
# period has 27 matches.
# dates_referenced has 822 matches.
# genre has 103568 matches.
# subgenre has 13825 matches.
# translation_source has 356 matches.
# provenience has 1032 matches.
# excavation_no has 8008 matches.
# findspot_square has 651 matches.
# date_of_origin has 8299 matches.
# museum_no has 59600 matches.
# collection has 38805 matches.
# designation has 40564 matches.

# %% [markdown]
# As we can see, there are no perfectly overlapping columns for CDLI and ORACC.

# %% [markdown]
# ## Subsets based on Object Type
#
# This section will have a heavier emphasis on tablet, envelope and cone objects.
#
# As a note, I think there are some incentives to keeping the CDLI and ORACC object type information separate from each other (object_type_x,object_type_y) so we can have a better idea of how each text was catalogued.
#
# **Understanding the Code Below:**
#
# Despite reasons to keep the object type columns separate, an alternate column (object_type_both) can be made by joining the string content of each column together to make quering through the metacatalogue easier. *This can be done for other columns with similar data information (e.g. period, language, ...)*
#
# In order to get the subset of the DF, we can look at if the object type column contains partial strings like 'ablet', 'nvelope', and 'one'. (This is shortcut way of not accounting for upper or lowercase starts to the words tablet, envelope, and cone.)
#
# As we'll see, the ORACC descriptions are either more descriptive (e.g. 'Envelope - Closed') or confusing (e.g. 'brick, stone block, tablet, door socket, cone').
#
# One can query through to find just tables, just envelopes, and just cones as seen in a following code cell.

# %%
#Run this cell to look at all types of objects presented from each catalogue in the metacatalogue
#print(metacatalogue['object_type_x'].unique())
#print(metacatalogue['object_type_y'].unique())

# %%
metacatalogue['object_type_both'] = metacatalogue['object_type_x'] + ', ' + metacatalogue['object_type_y']

# %%
subset = metacatalogue.loc[metacatalogue['object_type_both'].str.contains("ablet|nvelope|one")==True]
subset
# Out:
#        composite_id_x  id_text2  id_text    language_x object_type_x  \
# 0             Q000002       0.0  P000001  undetermined        tablet
# 1             Q000002       0.0  P000002  undetermined        tablet
# 2                 NaN       0.0  P000003  undetermined        tablet
# 3             Q000002       0.0  P000004  undetermined        tablet
# 4             Q000002       0.0  P000005  undetermined        tablet
# ...               ...       ...      ...           ...           ...
# 352907            NaN       0.0  P532071      Akkadian        tablet
# 352908            NaN       0.0  P532072      Akkadian        tablet
# 352909            NaN       0.0  P532073      Akkadian        tablet
# 352910            NaN       0.0  P532074      Akkadian        tablet
# 352911            NaN       0.0  P532075      Akkadian        tablet
#
#                                   period_x material_x  \
# 0              Uruk III (ca. 3200-3000 BC)       clay
# 1              Uruk III (ca. 3200-3000 BC)       clay
# 2               Uruk IV (ca. 3350-3200 BC)       clay
# 3               Uruk IV (ca. 3350-3200 BC)       clay
# 4               Uruk IV (ca. 3350-3200 BC)       clay
# ...                                    ...        ...
# 352907  Middle Assyrian (ca. 1400-1000 BC)       clay
# 352908  Middle Assyrian (ca. 1400-1000 BC)       clay
# 352909  Middle Assyrian (ca. 1400-1000 BC)       clay
# 352910  Middle Assyrian (ca. 1400-1000 BC)       clay
# 352911  Middle Assyrian (ca. 1400-1000 BC)       clay
#
#                                        collection_x museum_no_x  \
# 0         Vorderasiatisches Museum, Berlin, Germany   VAT 01533
# 1         Vorderasiatisches Museum, Berlin, Germany   VAT 15263
# 2         Vorderasiatisches Museum, Berlin, Germany   VAT 15253
# 3         Vorderasiatisches Museum, Berlin, Germany   VAT 15168
# 4         Vorderasiatisches Museum, Berlin, Germany   VAT 15153
# ...                                             ...         ...
# 352907  National Museum of Syria, Damascus, Syria ?         NaN
# 352908  National Museum of Syria, Damascus, Syria ?         NaN
# 352909  National Museum of Syria, Damascus, Syria ?         NaN
# 352910  National Museum of Syria, Damascus, Syria ?         NaN
# 352911                   British Museum, London, UK   BM 120122
#
#                      provenience_x excavation_no_x findspot_square_x  \
# 0                Uruk (mod. Warka)       W 06435,a         M XVIII,?
# 1                Uruk (mod. Warka)       W 06435,b         M XVIII,?
# 2                Uruk (mod. Warka)       W 09123,d          Qa XVI,2
# 3                Uruk (mod. Warka)       W 09169,d          Qa XVI,2
# 4                Uruk (mod. Warka)       W 09206,k          Qa XVI,2
# ...                            ...             ...               ...
# 352907     Kahat (mod. Tell Barri)      K21.E.3386               NaN
# 352908     Kahat (mod. Tell Barri)           K9.T1               NaN
# 352909     Kahat (mod. Tell Barri)           K9.T2               NaN
# 352910     Kahat (mod. Tell Barri)           K9.T3               NaN
# 352911  Assur (mod. Qalat Sherqat)             NaN               NaN
#
#        date_of_origin_x dates_referenced_x         genre_x  \
# 0           00.00.00.00        00.00.00.00         Lexical
# 1           00.00.00.00        00.00.00.00         Lexical
# 2                   NaN                NaN         Lexical
# 3           00.00.00.00        00.00.00.00         Lexical
# 4           00.00.00.00        00.00.00.00         Lexical
# ...                 ...                ...             ...
# 352907              NaN                NaN  Administrative
# 352908              NaN                NaN          Letter
# 352909              NaN                NaN          Letter
# 352910              NaN                NaN  Administrative
# 352911              NaN                NaN      Scientific
#
#                           subgenre_x translation_source_x  id  \
# 0            Archaic Lu2 A (witness)       no translation NaN
# 1            Archaic Lu2 A (witness)       no translation NaN
# 2       Archaic Vocabulary (witness)       no translation NaN
# 3            Archaic Lu2 A (witness)       no translation NaN
# 4            Archaic Lu2 A (witness)       no translation NaN
# ...                              ...                  ...  ..
# 352907                           NaN                  NaN NaN
# 352908                           NaN                  NaN NaN
# 352909                           NaN                  NaN NaN
# 352910                           NaN                  NaN NaN
# 352911                           NaN                  NaN NaN
#
#              language_y material_y object_type_y         period_y  \
# 0          undetermined       clay        tablet         Uruk III
# 1          undetermined       clay        tablet         Uruk III
# 2          undetermined       clay        tablet          Uruk IV
# 3          undetermined       clay        tablet          Uruk IV
# 4          undetermined       clay        tablet          Uruk IV
# ...                 ...        ...           ...              ...
# 352907  Middle Assyrian        NaN        tablet  Middle Assyrian
# 352908  Middle Assyrian        NaN        tablet  Middle Assyrian
# 352909  Middle Assyrian        NaN        tablet  Middle Assyrian
# 352910  Middle Assyrian        NaN        tablet  Middle Assyrian
# 352911  Middle Assyrian        NaN        tablet  Middle Assyrian
#
#                       provenience_y excavation_no_y findspot_square_y  \
# 0                      Warka (Uruk)             NaN               NaN
# 1                      Warka (Uruk)             NaN               NaN
# 2                      Warka (Uruk)             NaN               NaN
# 3                      Warka (Uruk)             NaN               NaN
# 4                      Warka (Uruk)             NaN               NaN
# ...                             ...             ...               ...
# 352907      Kahat (Mod. Tell Barri)             NaN               NaN
# 352908      Kahat (Mod. Tell Barri)             NaN               NaN
# 352909      Kahat (Mod. Tell Barri)             NaN               NaN
# 352910      Kahat (Mod. Tell Barri)             NaN               NaN
# 352911  Aššur (mod. Qalʿat Sherqat)             NaN               NaN
#
#        dates_referenced_y  genre_y    subgenre_y translation_source_y  \
# 0                     NaN  Lexical           NaN                  NaN
# 1                     NaN  Lexical           NaN                  NaN
# 2                     NaN  Lexical           NaN                  NaN
# 3                     NaN  Lexical           NaN                  NaN
# 4                     NaN  Lexical           NaN                  NaN
# ...                   ...      ...           ...                  ...
# 352907                NaN      NaN          Note                  NaN
# 352908                NaN      NaN  Letter order                  NaN
# 352909                NaN      NaN  Lexical List                  NaN
# 352910                NaN      NaN          List                  NaN
# 352911                NaN      NaN     Hippology                  NaN
#
#              archive                               collection_y museum-nos  \
# 0                NaN  Vorderasiatisches Museum, Berlin, Germany        NaN
# 1                NaN  Vorderasiatisches Museum, Berlin, Germany        NaN
# 2                NaN  Vorderasiatisches Museum, Berlin, Germany        NaN
# 3                NaN  Vorderasiatisches Museum, Berlin, Germany        NaN
# 4                NaN  Vorderasiatisches Museum, Berlin, Germany        NaN
# ...              ...                                        ...        ...
# 352907           NaN                                        NaN        NaN
# 352908           NaN                                        NaN        NaN
# 352909           NaN                                        NaN        NaN
# 352910           NaN                                        NaN        NaN
# 352911  M 02 Archive                                        NaN        NaN
#
#        mus_no museum_no_y cdli_museum_no saa_cdli_museum Mus_no museum_number  \
# 0         NaN         NaN            NaN             NaN    NaN           NaN
# 1         NaN         NaN            NaN             NaN    NaN           NaN
# 2         NaN         NaN            NaN             NaN    NaN           NaN
# 3         NaN         NaN            NaN             NaN    NaN           NaN
# 4         NaN         NaN            NaN             NaN    NaN           NaN
# ...       ...         ...            ...             ...    ...           ...
# 352907    NaN  K21.E.3386            NaN             NaN    NaN           NaN
# 352908    NaN       K9.T1            NaN             NaN    NaN           NaN
# 352909    NaN       K9.T2            NaN             NaN    NaN           NaN
# 352910    NaN       K9.T3            NaN             NaN    NaN           NaN
# 352911    NaN   BM 120122            NaN             NaN    NaN           NaN
#
#        museum museum_URL date_of_origin_y dialect date supergenre xproject  \
# 0         NaN        NaN              NaN     NaN  NaN        LEX     CDLI
# 1         NaN        NaN              NaN     NaN  NaN        LEX     CDLI
# 2         NaN        NaN              NaN     NaN  NaN        LEX     CDLI
# 3         NaN        NaN              NaN     NaN  NaN        LEX     CDLI
# 4         NaN        NaN              NaN     NaN  NaN        LEX     CDLI
# ...       ...        ...              ...     ...  ...        ...      ...
# 352907    NaN        NaN              NaN     NaN  NaN        NaN     CDLI
# 352908    NaN        NaN              NaN     NaN  NaN        NaN     CDLI
# 352909    NaN        NaN              NaN     NaN  NaN        NaN     CDLI
# 352910    NaN        NaN              NaN     NaN  NaN        NaN     CDLI
# 352911    NaN        NaN              NaN     NaN  NaN        NaN     CDLI
#
#        q_number ancient_year date_bce  cdli_id OBJ_type Period_culture  \
# 0           NaN          NaN      NaN  P000001      NaN            NaN
# 1           NaN          NaN      NaN  P000002      NaN            NaN
# 2           NaN          NaN      NaN  P000003      NaN            NaN
# 3           NaN          NaN      NaN  P000004      NaN            NaN
# 4           NaN          NaN      NaN  P000005      NaN            NaN
# ...         ...          ...      ...      ...      ...            ...
# 352907      NaN          NaN      NaN      NaN      NaN            NaN
# 352908      NaN          NaN      NaN      NaN      NaN            NaN
# 352909      NaN          NaN      NaN      NaN      NaN            NaN
# 352910      NaN          NaN      NaN      NaN      NaN            NaN
# 352911      NaN          NaN      NaN      NaN      NaN            NaN
#
#        Script_type_1 Genre Subgenre S_s_genre Language Full_no Tablet_number  \
# 0                NaN   NaN      NaN       NaN      NaN     NaN           NaN
# 1                NaN   NaN      NaN       NaN      NaN     NaN           NaN
# 2                NaN   NaN      NaN       NaN      NaN     NaN           NaN
# 3                NaN   NaN      NaN       NaN      NaN     NaN           NaN
# 4                NaN   NaN      NaN       NaN      NaN     NaN           NaN
# ...              ...   ...      ...       ...      ...     ...           ...
# 352907           NaN   NaN      NaN       NaN      NaN     NaN           NaN
# 352908           NaN   NaN      NaN       NaN      NaN     NaN           NaN
# 352909           NaN   NaN      NaN       NaN      NaN     NaN           NaN
# 352910           NaN   NaN      NaN       NaN      NaN     NaN           NaN
# 352911           NaN   NaN      NaN       NaN      NaN     NaN           NaN
#
#        Q_no object composite_id_y project name  id_text_int seal_id  \
# 0       NaN    NaN            NaN        armep          NaN     NaN
# 1       NaN    NaN            NaN        armep          NaN     NaN
# 2       NaN    NaN            NaN        armep          NaN     NaN
# 3       NaN    NaN            NaN        armep          NaN     NaN
# 4       NaN    NaN            NaN        armep          NaN     NaN
# ...     ...    ...            ...          ...          ...     ...
# 352907  NaN    NaN            NaN         tcma          NaN     NaN
# 352908  NaN    NaN            NaN         tcma          NaN     NaN
# 352909  NaN    NaN            NaN         tcma          NaN     NaN
# 352910  NaN    NaN            NaN         tcma          NaN     NaN
# 352911  NaN    NaN            NaN         tcma          NaN     NaN
#
#        cdli_composite_id ancient_date  bdtns_id object_type_both
# 0                    NaN          NaN       NaN   tablet, tablet
# 1                    NaN          NaN       NaN   tablet, tablet
# 2                    NaN          NaN       NaN   tablet, tablet
# 3                    NaN          NaN       NaN   tablet, tablet
# 4                    NaN          NaN       NaN   tablet, tablet
# ...                  ...          ...       ...              ...
# 352907               NaN          NaN       NaN   tablet, tablet
# 352908               NaN          NaN       NaN   tablet, tablet
# 352909               NaN          NaN       NaN   tablet, tablet
# 352910               NaN          NaN       NaN   tablet, tablet
# 352911               NaN          NaN       NaN   tablet, tablet
#
# [107753 rows x 68 columns]

# %% [markdown]
# To query the metacatalogue for a specific object type:
#
# ```
# metacatalogue.loc[metacatalogue['object_type_both'].str.contains('object_of_interest')==True]
# ```

# %% [markdown]
# For example here's a subset of the metacatalogue for objects that are marked as a type of seal.

# %%
subset_seal = metacatalogue.loc[metacatalogue['object_type_both'].str.contains('seal|Seal')==True]
subset_seal
# Out:
#        composite_id_x  id_text2  id_text language_x          object_type_x  \
# 9024              NaN       0.0  P100295   Sumerian                 tablet
# 24607             NaN       0.0  P115924   Sumerian                sealing
# 32007             NaN       0.0  P123204   Sumerian                 tablet
# 32008             NaN       0.0  P123205   Sumerian                 tablet
# 32010             NaN       0.0  P123207   Sumerian                 tablet
# ...               ...       ...      ...        ...                    ...
# 343013            NaN       0.0  P522007   Sumerian  seal (not impression)
# 343014            NaN       0.0  P522008   Sumerian  seal (not impression)
# 343015            NaN       0.0  P522009   Sumerian  seal (not impression)
# 343016            NaN       0.0  P522010   Sumerian  seal (not impression)
# 343017            NaN       0.0  P522011   Sumerian  seal (not impression)
#
#                          period_x material_x  \
# 9024    Ur III (ca. 2100-2000 BC)       clay
# 24607   Ur III (ca. 2100-2000 BC)       clay
# 32007   Ur III (ca. 2100-2000 BC)       clay
# 32008   Ur III (ca. 2100-2000 BC)       clay
# 32010   Ur III (ca. 2100-2000 BC)       clay
# ...                           ...        ...
# 343013  Ur III (ca. 2100-2000 BC)    stone ?
# 343014  Ur III (ca. 2100-2000 BC)    stone ?
# 343015  Ur III (ca. 2100-2000 BC)    stone ?
# 343016  Ur III (ca. 2100-2000 BC)    stone ?
# 343017  Ur III (ca. 2100-2000 BC)    stone ?
#
#                                              collection_x  museum_no_x  \
# 9024                  private: Böllinger, Endorf, Germany  Böllinger 6
# 24607      Bibliothèque de Versailles, Versailles, France        BV 19
# 32007   Oriental Institute, University of Chicago, Chi...       OIM A—
# 32008   Oriental Institute, University of Chicago, Chi...       OIM A—
# 32010   Oriental Institute, University of Chicago, Chi...       OIM A—
# ...                                                   ...          ...
# 343013                                                NaN          NaN
# 343014                                                NaN          NaN
# 343015                                                NaN          NaN
# 343016                                                NaN          NaN
# 343017                                                NaN          NaN
#
#                      provenience_x excavation_no_x findspot_square_x  \
# 9024    uncertain (mod. uncertain)             NaN               NaN
# 24607       Umma (mod. Tell Jokha)             NaN               NaN
# 32007    Ešnunna (mod. Tell Asmar)    TA 1930 0277               NaN
# 32008    Ešnunna (mod. Tell Asmar)    TA 1931 0320               NaN
# 32010    Ešnunna (mod. Tell Asmar)    TA 1931 0379               NaN
# ...                            ...             ...               ...
# 343013          Girsu (mod. Tello)             NaN               NaN
# 343014          Girsu (mod. Tello)             NaN               NaN
# 343015          Girsu (mod. Tello)             NaN               NaN
# 343016      Umma (mod. Tell Jokha)             NaN               NaN
# 343017          Girsu (mod. Tello)             NaN               NaN
#
#          date_of_origin_x dates_referenced_x         genre_x subgenre_x  \
# 9024          --.--.00.00        --.--.00.00  Administrative        NaN
# 24607         00.00.00.00        00.00.00.00  Administrative        NaN
# 32007      Šulgi.--.00.00     Šulgi.--.00.00  Administrative        NaN
# 32008   Amar-Sin.--.00.00  Amar-Sin.--.00.00  Administrative        NaN
# 32010         --.--.00.00        --.--.00.00  Administrative        NaN
# ...                   ...                ...             ...        ...
# 343013                NaN                NaN  Administrative        NaN
# 343014                NaN                NaN  Administrative        NaN
# 343015                NaN                NaN  Administrative        NaN
# 343016                NaN                NaN  Administrative        NaN
# 343017                NaN                NaN  Administrative        NaN
#
#        translation_source_x  id language_y material_y          object_type_y  \
# 9024         no translation NaN   Sumerian        NaN          Cylinder Seal
# 24607        no translation NaN   Sumerian        NaN                  Label
# 32007        no translation NaN   Sumerian        NaN           Clay sealing
# 32008        no translation NaN   Sumerian        NaN           Clay sealing
# 32010        no translation NaN   Sumerian        NaN           Clay sealing
# ...                     ...  ..        ...        ...                    ...
# 343013                  NaN NaN   Sumerian        NaN  seal (not impression)
# 343014                  NaN NaN   Sumerian        NaN  seal (not impression)
# 343015                  NaN NaN   Sumerian        NaN  seal (not impression)
# 343016                  NaN NaN   Sumerian        NaN  seal (not impression)
# 343017                  NaN NaN   Sumerian        NaN  seal (not impression)
#
#        period_y provenience_y excavation_no_y findspot_square_y  \
# 9024     Ur III       unknown             NaN               NaN
# 24607    Ur III          Umma             NaN               NaN
# 32007    Ur III       Ešnunna    TA 1930 0277               NaN
# 32008    Ur III       Ešnunna    TA 1931 0320               NaN
# 32010    Ur III       Ešnunna    TA 1931 0379               NaN
# ...         ...           ...             ...               ...
# 343013   Ur III         Girsu             NaN               NaN
# 343014   Ur III         Girsu             NaN               NaN
# 343015   Ur III         Girsu             NaN               NaN
# 343016   Ur III          Umma             NaN               NaN
# 343017   Ur III         Girsu             NaN               NaN
#
#        dates_referenced_y            genre_y subgenre_y translation_source_y  \
# 9024                  NaN     Administrative        NaN                  NaN
# 24607                 NaN     Administrative        NaN                  NaN
# 32007                 NaN     Administrative        NaN                  NaN
# 32008                 NaN  Royal Inscription        NaN                  NaN
# 32010                 NaN     Administrative        NaN                  NaN
# ...                   ...                ...        ...                  ...
# 343013                NaN     Administrative        NaN                  NaN
# 343014                NaN     Administrative        NaN                  NaN
# 343015                NaN     Administrative        NaN                  NaN
# 343016                NaN     Administrative        NaN                  NaN
# 343017                NaN     Administrative        NaN                  NaN
#
#        archive collection_y museum-nos mus_no   museum_no_y cdli_museum_no  \
# 9024       NaN          NaN        NaN    NaN  Boellinger 6            NaN
# 24607      NaN          NaN        NaN    NaN         BV 19            NaN
# 32007      NaN          NaN        NaN    NaN           NaN            NaN
# 32008      NaN          NaN        NaN    NaN           NaN            NaN
# 32010      NaN          NaN        NaN    NaN           NaN            NaN
# ...        ...          ...        ...    ...           ...            ...
# 343013     NaN          NaN        NaN    NaN           NaN            NaN
# 343014     NaN          NaN        NaN    NaN           NaN            NaN
# 343015     NaN          NaN        NaN    NaN           NaN            NaN
# 343016     NaN          NaN        NaN    NaN           NaN            NaN
# 343017     NaN          NaN        NaN    NaN           NaN            NaN
#
#        saa_cdli_museum Mus_no museum_number museum museum_URL  \
# 9024               NaN    NaN           NaN    NaN        NaN
# 24607              NaN    NaN           NaN    NaN        NaN
# 32007              NaN    NaN           NaN    NaN        NaN
# 32008              NaN    NaN           NaN    NaN        NaN
# 32010              NaN    NaN           NaN    NaN        NaN
# ...                ...    ...           ...    ...        ...
# 343013             NaN    NaN           NaN    NaN        NaN
# 343014             NaN    NaN           NaN    NaN        NaN
# 343015             NaN    NaN           NaN    NaN        NaN
# 343016             NaN    NaN           NaN    NaN        NaN
# 343017             NaN    NaN           NaN    NaN        NaN
#
#        date_of_origin_y dialect date supergenre xproject q_number  \
# 9024     0000 - 00 - 00     NaN  NaN        ELA     CDLI      NaN
# 24607    0000 - 00 - 00     NaN  NaN        ELA     CDLI      NaN
# 32007    0000 - 00 - 00     NaN  NaN        ELA     CDLI      NaN
# 32008    0000 - 00 - 00     NaN  NaN        LIT     CDLI      NaN
# 32010    0000 - 00 - 00     NaN  NaN        ELA     CDLI      NaN
# ...                 ...     ...  ...        ...      ...      ...
# 343013              NaN     NaN  NaN        ELA     CDLI      NaN
# 343014              NaN     NaN  NaN        ELA     CDLI      NaN
# 343015              NaN     NaN  NaN        ELA     CDLI      NaN
# 343016              NaN     NaN  NaN        ELA     CDLI      NaN
# 343017              NaN     NaN  NaN        ELA     CDLI      NaN
#
#        ancient_year date_bce cdli_id OBJ_type Period_culture Script_type_1  \
# 9024            NaN      NaN     NaN      NaN            NaN           NaN
# 24607           NaN      NaN     NaN      NaN            NaN           NaN
# 32007           NaN      NaN     NaN      NaN            NaN           NaN
# 32008           NaN      NaN     NaN      NaN            NaN           NaN
# 32010           NaN      NaN     NaN      NaN            NaN           NaN
# ...             ...      ...     ...      ...            ...           ...
# 343013          NaN      NaN     NaN      NaN            NaN           NaN
# 343014          NaN      NaN     NaN      NaN            NaN           NaN
# 343015          NaN      NaN     NaN      NaN            NaN           NaN
# 343016          NaN      NaN     NaN      NaN            NaN           NaN
# 343017          NaN      NaN     NaN      NaN            NaN           NaN
#
#        Genre Subgenre S_s_genre Language Full_no Tablet_number Q_no object  \
# 9024     NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# 24607    NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# 32007    NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# 32008    NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# 32010    NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# ...      ...      ...       ...      ...     ...           ...  ...    ...
# 343013   NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# 343014   NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# 343015   NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# 343016   NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
# 343017   NaN      NaN       NaN      NaN     NaN           NaN  NaN    NaN
#
#        composite_id_y project name  id_text_int seal_id cdli_composite_id  \
# 9024              NaN      babcity          NaN     NaN               NaN
# 24607             NaN      babcity          NaN     NaN               NaN
# 32007             NaN      babcity          NaN     NaN               NaN
# 32008             NaN      babcity          NaN     NaN               NaN
# 32010             NaN      babcity          NaN     NaN               NaN
# ...               ...          ...          ...     ...               ...
# 343013            NaN      babcity          NaN     NaN               NaN
# 343014            NaN      babcity          NaN     NaN               NaN
# 343015            NaN      babcity          NaN     NaN               NaN
# 343016            NaN      babcity          NaN     NaN               NaN
# 343017            NaN      babcity          NaN     NaN               NaN
#
#        ancient_date  bdtns_id                              object_type_both
# 9024            NaN   18056.0                         tablet, Cylinder Seal
# 24607           NaN   23252.0                                sealing, Label
# 32007           NaN   12191.0                          tablet, Clay sealing
# 32008           NaN   12192.0                          tablet, Clay sealing
# 32010           NaN   12194.0                          tablet, Clay sealing
# ...             ...       ...                                           ...
# 343013          NaN       NaN  seal (not impression), seal (not impression)
# 343014          NaN       NaN  seal (not impression), seal (not impression)
# 343015          NaN       NaN  seal (not impression), seal (not impression)
# 343016          NaN       NaN  seal (not impression), seal (not impression)
# 343017          NaN       NaN  seal (not impression), seal (not impression)
#
# [6472 rows x 68 columns]

# %% [markdown]
# #Important Counts & Exporting the Metacatalogue:
#
# Metacatalogue : 366916 rows × 46 columns
#
# Matching IDs : 157512 texts
#
# Tablet Texts : 102035
#
# Envelope Texts : 3798
#
# Cone Texts : 5667
#
# Seal Texts : 6472

# %%
#exports metacatalogue to the folder ORACC_DFS
metacatalogue.to_csv(folder + 'ORACC_DFS/metacatalogue.csv')
