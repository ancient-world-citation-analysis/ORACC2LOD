# %% [markdown]
# # Download ORACC Directory ZIP Files (Google Colab version)

# %% [markdown]
# Author: Melinee Her, Tiffany Lee

# %% [markdown]
# **Melinee Her** - Summer 2023
#
# Context:
# Taking the methods Tiffany set up, my goal is to capture all directories for ORACC projects and download all corresponding zip files.
#
# **Tiffany Lee** - Summer 2022
#
# Context: Last April, I was trying to use utilities from [Computational Assyriology (Compass)](https://github.com/niekveldhuis/compass), a project by Professor Niek Veldhuis, to download datasets from various databases. What I found was that his tool uses the file paths of the [Oracc: The Open Richly Annotated Cuneiform Corpus](http://oracc.museum.upenn.edu/) database to download zip files of the datasets. With that in mind, I needed to produce a list of file paths to automate the process of downloading.
#
# This notebook seeks to explore solutions to produce a list of file paths/URLs and download the ZIP files corresponding to the items in the list.

# %% [markdown]
# # Notebook Setup

# %% [markdown]
# ## Mount Google Drive folder

# %% [markdown]
# The code snippet below is to mount Google Drive files so that we can interact with our Google Drive files using the file browser or command line. Running it will give a permissions prompt.

# %%
from google.colab import drive
drive.mount('/content/drive')

#Set folder for remote drive
#folder = '/content/drive/My Drive/FactGrid Cuneiform (AWCA)/people/Melinee'
folder = '/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Load Libraries

# %% [markdown]
# Next, we load the libraries needed for this notebook. There will also be code prompts below to load libraries in case any user wants to run only a portion of the notebook instead of the whole thing.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm.auto import tqdm
import os
import ipywidgets as widgets
from zipfile import ZipFile
from urllib.request import urlopen

#added imports
import re

# %% [markdown]
# ## Create Download Directory
# Create a directory called `ORACC_zips`. If the directory already exists, do nothing. We can change this directory according to what is needed.

# %%
os.makedirs(folder + "/ORACC_zips", exist_ok = True)

# %% [markdown]
# # Obtain Zip File File Paths from [Oracc](http://oracc.museum.upenn.edu/) Projects Page

# %% [markdown]
# Before we can download, we need to know where to download the data for the projects. In the [Compass](https://github.com/niekveldhuis/compass) repository, Professor Veldhuis identified the pattern of the URLs corresponding to the ZIP files for the project data used the following format: "http://oracc.museum.upenn.edu/json/asbp.zip".
#
# I noticed that the links on the [Oracc Project List](http://oracc.museum.upenn.edu/projectlist.html) page followed the pattern in the URL provided above. I thought it would be a good idea to compile a list of project ZIP file URLs by extracting it from [Oracc Project List](http://oracc.museum.upenn.edu/projectlist.html). To do so, I found a Stack Overflow solution to extract website file paths with the `requests` and `bs4` libraries ([How to extract URLs from an HTML page in Python - Stack Overflow](https://stackoverflow.com/questions/15517483/how-to-extract-urls-from-an-html-page-in-python)).
#
# Thus, this part seeks to obtain the file paths for the ZIP files of each project linked on the ORACC Project Page to prepare for the downloads. Later, we will use the file paths to prepare formatted download URLs to download the project ZIP files.

# %% [markdown]
# ### Define `getFilePathListFromURL` Method

# %%
def getFilePath(page, tofind):
    """
    :param page: html of web page
    :param tofind: html element to search for
    :return urls or file paths in that page
    This is a utility method for getFilePathListFromHTMLPage().
    """
    start_link = page.find(tofind)
    if start_link == -1:
        return None, 0
    start_quote = page.find('"', start_link)
    end_quote = page.find('"', start_quote + 1)
    url = page[start_quote + 1: end_quote]
    return url, end_quote

def getFilePathListFromURL(source_url, tofind):
    """
    :param source_url: url of the source web page that we will extract file
                       paths from
    :return path_list: list of file paths in the source_url page
    """
    response = requests.get(source_url)
    page = str(BeautifulSoup(response.content))
    path_list = []
    while True:
        path, n = getFilePath(page, tofind)
        page = page[n:]
        if path:
            path_list.append(path)
        else:
            break
    return path_list

# %% [markdown]
# Run `getFilePathListFromURL` Method on the Oracc Project List to retrieve a list of all hyperlinked url paths

# %%
project_path_list = getFilePathListFromURL("http://oracc.museum.upenn.edu/projectlist.html", 'a href')
project_path_list[:5]
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# ['/',
#  './adsd',
#  './adsd',
#  'https://oeaw.academia.edu/ReinhardPirngruber',
#  './adsd/adart1']

# %% [markdown]
# ## Formatting the File Paths

# %% [markdown]
# Now we have a list of project ZIP file paths in the [Oracc](http://oracc.museum.upenn.edu/) website. However, we will need to do some clean up and formatting to make it easier for utilties to download the files. Some observations I have made include the following:

# %% [markdown]
# (1) I noticed that the project directory itself was listed as part of the paths (`/`) but it is redundant so I will remove the first item in the list.
#
# (2) Since the download widget doesn't take relative paths and only the project names and their corresponding subproject path, I will be removing the `./` part of the paths.
#
# (3) While the website addresses with "http", "https", and "www", may be useful for metadata purposes, I think it's best to filter them out for now.
#
# (4) Removed duplicates in url_list too.

# %% [markdown]
# ### Define `FormatFilePathListForDownload()` Method

# %%
def FormatFilePathListForDownload(project_list):
  """
  :param project_list: list of project file paths
  :return project_list_formatted: list of formatted project file paths
  """
  project_list_formatted = []

  #deletes of any unintentional hyperlinks found
  for path in project_list[1:]:
    if ("http") in path:
      continue;
    elif ("www") in path:
      continue;
    else:
      project_list_formatted.append(path[2:])

  #deletes duplicates
  project_list_formatted = [url for n, url in enumerate(project_list_formatted) if url not in project_list_formatted[:n]]
  return project_list_formatted

# %% [markdown]
# ### Run `FormatFilePathListForDownload()` Method
# This cleans up the original list of urls to include only the project and subproject paths.

# %%
project_path_list_clean = FormatFilePathListForDownload(project_path_list)
project_path_list_clean
# Out:
# ['adsd',
#  'adsd/adart1',
#  'adsd/adart2',
#  'adsd/adart3',
#  'adsd/adart5',
#  'adsd/adart6',
#  'aemw',
#  'aemw/alalakh/idrimi',
#  'aemw/amarna',
#  'akklove',
#  'amgg',
#  'ario',
#  'armep',
#  'arrim',
#  'asbp',
#  'asbp/ninmed',
#  'asbp/rlasb',
#  'atae',
#  'atae/assur',
#  'atae/burmarina',
#  'atae/durkatlimmu',
#  'atae/durszarrukin',
#  'atae/guzana',
#  'atae/huzirina',
#  'atae/imgurenlil',
#  'atae/kalhu',
#  'atae/kunalia',
#  'atae/mallanate',
#  'atae/marqasu',
#  'atae/nineveh',
#  'atae/samal',
#  'atae/szibaniba',
#  'atae/tilbarsip',
#  'atae/tuszhan',
#  'babcity',
#  'blms',
#  'borsippa',
#  'btmao',
#  'btto',
#  'cams',
#  'cams/akno',
#  'cams/anzu',
#  'cams/barutu',
#  'cams/etana',
#  'cams/gkab',
#  'cams/ludlul',
#  'cams/selbi',
#  'cams/tlab',
#  'cdli',
#  'ckst',
#  'cmawro',
#  'cmawro/cmawr1',
#  'cmawro/cmawr2',
#  'cmawro/cmawr3',
#  'cmawro/maqlu',
#  'contrib',
#  'contrib/amarna',
#  'contrib/lambert',
#  'ctij',
#  'dcclt',
#  'dcclt/ebla',
#  'dcclt/jena',
#  'dcclt/nineveh',
#  'dcclt/signlists',
#  'dccmt',
#  'dsst',
#  'ecut',
#  'eisl',
#  'epsd2',
#  'etcsri',
#  'glass',
#  'hbtin',
#  'lacost',
#  'lovelyrics',
#  'nere',
#  'nimrud',
#  'obel',
#  'obmc',
#  'obta',
#  'ogsl',
#  'oimea',
#  'pnao',
#  'qcat',
#  'riao',
#  'ribo',
#  'ribo/bab7scores',
#  'ribo/babylon10',
#  'ribo/babylon2',
#  'ribo/babylon3',
#  'ribo/babylon4',
#  'ribo/babylon5',
#  'ribo/babylon6',
#  'ribo/babylon7',
#  'ribo/babylon8',
#  'ribo/sources',
#  'rimanum',
#  'rinap',
#  'rinap/rinap1',
#  'rinap/rinap2',
#  'rinap/rinap3',
#  'rinap/rinap4',
#  'rinap/rinap5',
#  'rinap/rinap5p1',
#  'rinap/scores',
#  'rinap/sources',
#  'saao',
#  'saao/aebp',
#  'saao/knpp',
#  'saao/saa01',
#  'saao/saa02',
#  'saao/saa03',
#  'saao/saa04',
#  'saao/saa05',
#  'saao/saa06',
#  'saao/saa07',
#  'saao/saa08',
#  'saao/saa09',
#  'saao/saa10',
#  'saao/saa11',
#  'saao/saa12',
#  'saao/saa13',
#  'saao/saa14',
#  'saao/saa15',
#  'saao/saa16',
#  'saao/saa17',
#  'saao/saa18',
#  'saao/saa19',
#  'saao/saa20',
#  'saao/saa21',
#  'saao/saas2',
#  'suhu',
#  'tcma',
#  'tsae',
#  'urap',
#  'xcat']

# %% [markdown]
# ### Optional: Concatenate the list to single string instead of a list of strings

# %% [markdown]
# If we want to use some of Professor Veldhuis' [Compass](https://github.com/niekveldhuis/compass) utilities, it is helpful to have the path list be a single string.

# %%
project_path_list_clean_string = ', '.join([url for url in project_path_list_clean])
project_path_list_clean_string
# Out:
# 'adsd, adsd/adart1, adsd/adart2, adsd/adart3, adsd/adart5, adsd/adart6, aemw, aemw/alalakh/idrimi, aemw/amarna, akklove, amgg, ario, armep, arrim, asbp, asbp/ninmed, asbp/rlasb, atae, atae/assur, atae/burmarina, atae/durkatlimmu, atae/durszarrukin, atae/guzana, atae/huzirina, atae/imgurenlil, atae/kalhu, atae/kunalia, atae/mallanate, atae/marqasu, atae/nineveh, atae/samal, atae/szibaniba, atae/tilbarsip, atae/tuszhan, babcity, blms, borsippa, btmao, btto, cams, cams/akno, cams/anzu, cams/barutu, cams/etana, cams/gkab, cams/ludlul, cams/selbi, cams/tlab, cdli, ckst, cmawro, cmawro/cmawr1, cmawro/cmawr2, cmawro/cmawr3, cmawro/maqlu, contrib, contrib/amarna, contrib/lambert, ctij, dcclt, dcclt/ebla, dcclt/jena, dcclt/nineveh, dcclt/signlists, dccmt, dsst, ecut, eisl, epsd2, etcsri, glass, hbtin, lacost, lovelyrics, nere, nimrud, obel, obmc, obta, ogsl, oimea, pnao, qcat, riao, ribo, ribo/bab7scores, ribo/babylon10, ribo/babylon2, ribo/babylon3, ribo/babylon4, ribo/babylon5, ribo/babylon6, ribo/babylon7, ribo/babylon8, ribo/sources, rimanum, rinap, rinap/rinap1, rinap/rinap2, rinap/rinap3, rinap/rinap4, rinap/rinap5, rinap/rinap5p1, rinap/scores, rinap/sources, saao, saao/aebp, saao/knpp, saao/saa01, saao/saa02, saao/saa03, saao/saa04, saao/saa05, saao/saa06, saao/saa07, saao/saa08, saao/saa09, saao/saa10, saao/saa11, saao/saa12, saao/saa13, saao/saa14, saao/saa15, saao/saa16, saao/saa17, saao/saa18, saao/saa19, saao/saa20, saao/saa21, saao/saas2, suhu, tcma, tsae, urap, xcat'

# %% [markdown]
# #Digging for more corpuses
# There are some projects [e.g. epsd2, tcma] that have buried corpuses on their respective Oracc Project Pages.
#
# Note: These were found with a knowledge of which projects have a buried corpuses. No method can be generalized to find buried corpuses because each project website varies in hyperlinks, paths, and style.

# %%
buried = ['epsd2/earlylit', 'epsd2/literary', 'epsd2/praxis', 'epsd2/praxis/liturgy', "tcma/ali1",
      'epsd2/admin/ebla', 'epsd2/admin/ed12', 'epsd2/admin/ed3b', 'epsd2/admin/lagash2',
      'epsd2/admin/oakk', 'epsd2/admin/oldbab', 'epsd2/admin/ur3',

      "tcma/amarna","tcma/assur","tcma/barri","tcma/bazmusian","tcma/billa", "tcma/brak","tcma/chuera","tcma/emar",
      "tcma/fekheriye","tcma/giricano","tcma/hana","tcma/haradum","tcma/hatti","tcma/kalhu","tcma/kartn","tcma/kulishinas",
      "tcma/miscellaneous","tcma/nineveh","tcma/nippur","tcma/nuzi","tcma/qitar","tcma/rimah","tcma/suri",
      "tcma/taban","tcma/tsa1","tcma/tsh1","tcma/ugarit"]

# %%
final = project_path_list_clean + buried

# %% [markdown]
# # Download Method 1: Use [Compass](https://github.com/niekveldhuis/compass) code

# %% [markdown]
# First, let's try using the Compass method of downloading [Oracc](http://oracc.museum.upenn.edu/) project files.

# %% [markdown]
# Quoted from [compass/2_1_0_download_ORACC-JSON.ipynb](https://github.com/niekveldhuis/compass/blob/master/2_1_Data_Acquisition_ORACC/2_1_0_download_ORACC-JSON.ipynb):
#
# > For larger projects (such as [DCCLT](http://oracc.org/dcclt)) the `zip` file may be 25Mb or more. Downloading may take some time and it may be necessary to chunk the downloading process. The `iter_content()` function in the `requests` library takes care of that.
#
# > In order to show a progress bar (with `tqdm`) we need to know how large the file to be downloaded is (this value is is then fed to the `total` parameter). The http protocol provides a key `content-length` in the headers (a dictionary) that indicates file length. Not all servers provide this field - if `content-length` is not avalaible it is set to 0. With the `total` value of 0 `tqdm` will show a bar and will count the number of chunks received, but it will not indicate the degree of progress.

# %% [markdown]
# ## Define `downloadProjectsWithCompass()` Method

# %%
import requests
from tqdm.auto import tqdm

# %%
def downloadProjectsWithCompass(project_list, destination):
  """
  :param project_list: list of project file paths
  :param destination: destination directory to put the downloaded files in
  :return download_url_list: list of formatted download links of project ZIP
                             files that were successfully download
  :return url_not_found_list: list of formatted download links of project ZIP
                              files that failed to download
  """
  CHUNK = 1024
  download_url_list = []
  url_not_found_list = []
  for project in project_list:
      proj = project.replace('/', '-')
      url = f"http://oracc.museum.upenn.edu/json/{proj}.zip"
      #file = f'jsonzip/{proj}.zip'
      #file = f'drive/MyDrive/AWCA/tablet_zip/ORACC/{proj}.zip'
      file = f'{destination}/{proj}.zip'
      with requests.get(url, stream=True) as request:
          if request.status_code == 200:   # meaning that the file exists
              total_size = int(request.headers.get('content-length', 0))
              tqdm.write(f'Saving {url} as {file}')
              t=tqdm(total=total_size, unit='B', unit_scale=True, desc = project)
              with open(file, 'wb') as f:
                  for c in request.iter_content(chunk_size=CHUNK):
                      t.update(len(c))
                      f.write(c)
              download_url_list.append(url)
          else:
              tqdm.write(f"WARNING: {url} does not exist.")
              url_not_found_list.append(url)
  return download_url_list, url_not_found_list

# %% [markdown]
# ## Run `downloadProjectsWithCompass()` Method

# %% [markdown]
# Set the destination directory and run the `downloadProjectsWithCompass()` method with the necessary parameters.

# %%
destination = folder + 'ORACC_zips'
download_url_list, url_not_found_list = downloadProjectsWithCompass(fix, destination)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-812a43458a6b> in <cell line: 2>()
#       1 destination = folder + 'ORACC_zips'
# ----> 2 download_url_list, url_not_found_list = downloadProjectsWithCompass(fix, destination)
#
# NameError: name 'fix' is not defined

# %%
destination = folder + 'ORACC_zips'
download_url_list, url_not_found_list = downloadProjectsWithCompass(buried, destination)

# %% [markdown]
# ## Examine Downloaded Files in Destination Directory

# %% [markdown]
# Use bash `ls` command to check the contents of the directory after downloading.

# %%
# !ls drive/MyDrive/Melinee/ORACC_zips

# %% [markdown]
# Examine the successful download URLs.

# %%
download_url_list

# %% [markdown]
# Examine the failed download URLs.

# %%
url_not_found_list

# %% [markdown]
# # Download Method 2: Download using Stack Overflow code

# %% [markdown]
# Using the links generated from some modified [Compass](https://github.com/niekveldhuis/compass) code from the above method, we can obtain the download links to the project ZIP files.
#
# I found a solution from Stack Overflow using the `os` and `requests` libraries to perform this process: [Download file from URL and save it in a folder Python - Stack Overflow](https://stackoverflow.com/questions/56950987/download-file-from-url-and-save-it-in-a-folder-python). Somehow it runs *slower* when not using Google Colab Notebook though.

# %% [markdown]
# ### Define `downloadProjectsWithStackOverflow()` Method and associated utility methods

# %%
import os
from tqdm.auto import tqdm
import requests

# %%
def getDownloadURL(file_path):
  """
  :param file: a file path
  :return url: a formatted download URL
  :return url_exists: True if a url exists, False if a url doesn't exist
  This is a utility method for getDownloadURLList() to prepare a formatted
  download URL.
  """
  file = file_path.replace('/', '-')
  url = f"http://oracc.museum.upenn.edu/json/{file}.zip"
  url_exists = False
  with requests.get(url, stream=True) as request:
    if request.status_code == 200:   # meaning that the file exists
      print(f"SUCCESS: {url} exists.")
      url_exists = True
    else:
      print(f"WARNING: {url} does not exist.")
      url_exists = False
  return url, url_exists

# %%
def getDownloadURLList(file_path_list):
  """
  :param file_path_list: list of file paths
  :return download_url_list: list of formatted download links of project ZIP
                             files that were successfully download
  :return url_not_found_list: list of formatted download links of project ZIP
                              files that failed to download
  This is a utility method for downloadProjectsWithStackOverflow() to
  prepare a list of URLs to download the project ZIP files.
  """
  download_url_list = []
  url_not_found_list = []
  for file_path in file_path_list:
    url, url_exists = getDownloadURL(file_path)
    if url_exists:
      download_url_list.append(url)
    else:
      url_not_found_list.append(url)
  return download_url_list, url_not_found_list

# %%
def downloadFile(url: str, destination: str):
#    if not os.path.exists(destination):
#        os.makedirs(destination)  # create folder if it does not exist
    """
    :param url: URL of file to download
    :param destination: destination directory to put the downloaded files in
    This is a utility method for downloadProjectsWithStackOverflow() to
    download a single file given a URL and a destination directory path.
    """
    filename = url.split('/')[-1].replace(" ", "_")  # be careful with file names
    file_path = os.path.join(destination, filename)

    r = requests.get(url, stream=True)
    if r.ok:
        print("saving to", os.path.abspath(file_path))
        with open(file_path, 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024 * 8):
                if chunk:
                    f.write(chunk)
                    f.flush()
                    os.fsync(f.fileno())
    else:  # HTTP status code 4XX/5XX
        print("Download failed: status code {}\n{}".format(r.status_code, r.text))

# %%
def downloadProjectsWithStackOverflow(project_list, destination):
  """
  :param project_list: list of project file paths
  :param destination: destination directory to put the downloaded files in
  :return download_url_list: list of formatted download links of project ZIP
                             files that were successfully download
  :return url_not_found_list: list of formatted download links of project ZIP
                              files that failed to download
  """
  download_url_list, url_not_found_list = getDownloadURLList(project_list)
  for url in download_url_list:
    downloadFile(url, destination)
  return download_url_list, url_not_found_list

# %% [markdown]
# ## Run `downloadProjectsWithStackOverflow()` Method

# %% [markdown]
# Use bash `ls` command to check the contents of the destination directory before running the `downloadProjectsWithStackOverflow()` method.

# %%
# !ls /content/drive/MyDrive/Melinee/ORACC_zips

# %%
destination = folder + "ORACC_zips"
download_url_list, url_not_found_list = downloadProjectsWithStackOverflow(project_path_list_clean, destination)
# Out:
# SUCCESS: http://oracc.museum.upenn.edu/json/adsd.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/adsd-adart1.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/adsd-adart2.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/adsd-adart3.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/adsd-adart5.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/adsd-adart6.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/aemw.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/aemw-alalakh-idrimi.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/aemw-amarna.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/akklove.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/amgg.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ario.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/armep.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/arrim.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/asbp.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/asbp-ninmed.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/asbp-rlasb.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-assur.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-burmarina.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-durkatlimmu.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-durszarrukin.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-guzana.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-huzirina.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-imgurenlil.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-kalhu.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-kunalia.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-mallanate.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-marqasu.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-nineveh.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-samal.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-szibaniba.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-tilbarsip.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-tuszhan.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/babcity.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/blms.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/borsippa.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/btmao.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/btto.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams-akno.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams-anzu.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams-barutu.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams-etana.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams-gkab.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams-ludlul.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams-selbi.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams-tlab.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cdli.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ckst.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cmawro.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cmawro-cmawr1.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cmawro-cmawr2.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cmawro-cmawr3.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cmawro-maqlu.zip exists.
# WARNING: http://oracc.museum.upenn.edu/json/contrib.zip does not exist.
# SUCCESS: http://oracc.museum.upenn.edu/json/contrib-amarna.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/contrib-lambert.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ctij.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/dcclt.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/dcclt-ebla.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/dcclt-jena.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/dcclt-nineveh.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/dcclt-signlists.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/dccmt.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/dsst.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ecut.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/eisl.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/epsd2.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/etcsri.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/glass.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/hbtin.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/lacost.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/lovelyrics.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/nere.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/nimrud.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/obel.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/obmc.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/obta.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ogsl.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/oimea.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/pnao.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/qcat.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/riao.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-bab7scores.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-babylon10.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-babylon2.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-babylon3.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-babylon4.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-babylon5.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-babylon6.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-babylon7.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-babylon8.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-sources.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rimanum.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap-rinap1.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap-rinap2.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap-rinap3.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap-rinap4.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap-rinap5.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap-rinap5p1.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap-scores.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap-sources.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-aebp.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-knpp.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa01.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa02.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa03.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa04.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa05.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa06.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa07.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa08.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa09.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa10.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa11.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa12.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa13.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa14.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa15.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa16.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa17.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa18.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa19.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa20.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa21.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saas2.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/suhu.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/tcma.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/tsae.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/urap.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/xcat.zip exists.
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/adsd.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/adsd-adart1.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/adsd-adart2.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/adsd-adart3.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/adsd-adart5.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/adsd-adart6.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/aemw.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/aemw-alalakh-idrimi.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/aemw-amarna.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/akklove.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/amgg.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/ario.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/armep.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/arrim.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/asbp.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/asbp-ninmed.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/asbp-rlasb.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae-assur.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae-burmarina.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae-durkatlimmu.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae-durszarrukin.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae-guzana.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae-huzirina.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae-imgurenlil.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae-kalhu.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae-kunalia.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae-mallanate.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae-marqasu.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae-nineveh.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae-samal.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae-szibaniba.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae-tilbarsip.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/atae-tuszhan.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/babcity.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/blms.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/borsippa.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/btmao.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/btto.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/cams.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/cams-akno.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/cams-anzu.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/cams-barutu.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/cams-etana.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/cams-gkab.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/cams-ludlul.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/cams-selbi.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/cams-tlab.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/cdli.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/ckst.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/cmawro.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/cmawro-cmawr1.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/cmawro-cmawr2.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/cmawro-cmawr3.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/cmawro-maqlu.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/contrib-amarna.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/contrib-lambert.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/ctij.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/dcclt.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/dcclt-ebla.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/dcclt-jena.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/dcclt-nineveh.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/dcclt-signlists.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/dccmt.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/dsst.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/ecut.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/eisl.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/epsd2.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/etcsri.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/glass.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/hbtin.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/lacost.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/lovelyrics.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/nere.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/nimrud.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/obel.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/obmc.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/obta.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/ogsl.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/oimea.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/pnao.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/qcat.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/riao.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/ribo.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/ribo-bab7scores.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/ribo-babylon10.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/ribo-babylon2.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/ribo-babylon3.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/ribo-babylon4.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/ribo-babylon5.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/ribo-babylon6.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/ribo-babylon7.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/ribo-babylon8.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/ribo-sources.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/rimanum.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/rinap.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/rinap-rinap1.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/rinap-rinap2.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/rinap-rinap3.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/rinap-rinap4.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/rinap-rinap5.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/rinap-rinap5p1.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/rinap-scores.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/rinap-sources.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-aebp.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-knpp.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa01.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa02.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa03.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa04.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa05.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa06.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa07.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa08.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa09.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa10.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa11.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa12.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa13.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa14.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa15.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa16.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa17.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa18.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa19.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa20.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saa21.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/saao-saas2.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/suhu.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/tcma.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/tsae.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/urap.zip
# saving to /content/drive/MyDrive/FactGrid Cuneiform (AWCA)/people/Melinee/ORACC_zips/xcat.zip

# %% [markdown]
# ## Examine the Downloaded Files in the Destination Directory

# %% [markdown]
# Use bash `ls` command to check if we downloaded the files we needed.

# %%
# !ls /content/drive/MyDrive/Melinee/ORACC_zips

# %% [markdown]
# Examine the successful download URLs.

# %%
download_url_list

# %% [markdown]
# Examine the failed download URLs.

# %%
url_not_found_list
